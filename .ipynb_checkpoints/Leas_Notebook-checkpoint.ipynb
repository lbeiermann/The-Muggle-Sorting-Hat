# %% [markdown]
# # K-means clustering

# %% [markdown]
# ## Exploratory data analysis: mall customer segmentation data (kaggle)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

df1 = pd.read_csv("The Muggle Sorting Hat DataSet.csv")
df1["Gender"] = df1["Gender"].str.replace(" ", "")
df1["District"] = df1["District"].str.replace(" ", "")
df1["Name"] = df1["Name"].str.replace(" ", "")
df1["Friend 1"] = df1["Friend 1"].str.replace(" ", "")
df1["Friend 2 "] = df1["Friend 2 "].str.replace(" ", "")
df1.rename(columns = {"Friend 2 ":"Friend 2"}, inplace = True)
df1.head()
# Out:
#             Name  Gender  Age District      Friend 1      Friend 2
# 0   BettyAllison  female   10  Pandora     MollyMeer  JessicaZebra
# 1     PeterAlexs    male   10    Limsa   G�ntherCohl   CeasarFeige
# 2  GregorAllmann    male   11  Pandora    BertEdamer   CeasarFeige
# 3   TiffanyBecks  female   10  Pandora      AllyInka     SallyBrot
# 4      SallyBrot  female   10    Limsa  TiffanyBecks  BettyAllison

# %%
#df1.rename(columns = {"Annual Income (k$)":"Income", "Spending Score (1-100)":"Spending Score"}, inplace = True)
#df1.head()

# %%
df1.describe()
# Out:
#              Age
# count  80.000000
# mean   10.112500
# std     0.317974
# min    10.000000
# 25%    10.000000
# 50%    10.000000
# 75%    10.000000
# max    11.000000

# %%
sns.pairplot(df1[["Age", "District", "Gender"]])

# %%
df1["District"].value_counts()
# Out:
# Pandora       19
# Uldah         17
# Limsa         15
# Queensdale    11
# Gridania      11
# Reach          7
# Name: District, dtype: int64

# %%
dic = {"Pandora" : "0", "Uldah" : "1", "Limsa" : "2", "Queensdale" : "3", "Gridania" : "4", "Reach" : "5"}
dic2 = {"female" : "0", "male" : "1"}

for old, new in dic.items():
    df1['District'] = df1['District'].str.replace(old, new, regex=False)

for old, new in dic2.items():
    df1['Gender'] = df1['Gender'].str.replace(old, new, regex=False)

df1['District'] = df1['District'].astype(int)
df1['Gender'] = df1['Gender'].astype(int)

# %%
df1.head()
df1["Gender"].value_counts()
# Out:
# 1    41
# 0    39
# Name: Gender, dtype: int64

# %% [markdown]
# ## Clustering mall customer segmentation data

# %%
import sklearn.cluster as cluster
kmeans = cluster.KMeans(n_clusters = 5, init = "k-means++", random_state = 42)
kmeans = kmeans.fit(df1[["District", "Gender"]])
kmeans.cluster_centers_
# Out:
# array([[ 2.54545455e+00, -1.11022302e-16],
#        [ 4.38888889e+00,  5.55555556e-01],
#        [ 0.00000000e+00,  2.63157895e-01],
#        [ 1.00000000e+00,  6.47058824e-01],
#        [ 2.33333333e+00,  1.00000000e+00]])

# %%
df1["Clusters"] = kmeans.labels_
df1.head(10)
# Out:
#             Name  Gender  Age  District      Friend 1          Friend 2  \
# 0   BettyAllison       0   10         0     MollyMeer      JessicaZebra
# 1     PeterAlexs       1   10         2   G�ntherCohl       CeasarFeige
# 2  GregorAllmann       1   11         0    BertEdamer       CeasarFeige
# 3   TiffanyBecks       0   10         0      AllyInka         SallyBrot
# 4      SallyBrot       0   10         2  TiffanyBecks      BettyAllison
# 5     NancyClick       0   11         1     ZoeJutter  AmandaFredericks
# 6    G�ntherCohl       1   10         1   CeasarFeige        PeterAlexs
# 7    JohnnyCedar       1   10         4   MarvinGeige        LeoJackson
# 8   MathildaDamm       0   10         2  YuleHoffnung         ZoeJutter
# 9     BertEdamer       1   10         1    PeterAlexs       G�ntherCohl
#
#    Clusters
# 0         2
# 1         4
# 2         2
# 3         2
# 4         0
# 5         3
# 6         3
# 7         1
# 8         0
# 9         3

# %%
df1["Clusters"].value_counts()
# Out:
# 2    19
# 1    18
# 3    17
# 4    15
# 0    11
# Name: Clusters, dtype: int64

# %%
sns.scatterplot(data = df1, x = "Age", y = "District", hue = "Clusters", palette = "Set2")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='District'>

# %% [markdown]
# ## Creating diverse customer groups

# %%
"""
First function creates list a of clustered dataframes (one df per cluster); second function takes list a,
splits clustered dataframes into required number of diverse groups (splits) and adds them to list b; third function 
combines splitted dataframes in list b into new (diverse) dataframes and adds them to list c.
"""
#from functools import reduce

def create_clustered_dataframes(df):
    dataframes = []
    for i in df.Clusters.unique():
        temporary_df = df[df["Clusters"] == i]
        dataframes.append(temporary_df)
    return dataframes

clustered_dataframes = create_clustered_dataframes(df1)
clustered_dataframes[0]
# Out:
#                 Name  Gender  Age  District        Friend 1          Friend 2  \
# 0       BettyAllison       0   10         0       MollyMeer      JessicaZebra
# 2      GregorAllmann       1   11         0      BertEdamer       CeasarFeige
# 3       TiffanyBecks       0   10         0        AllyInka         SallyBrot
# 10  AmandaFredericks       0   11         0      NancyClick      TiffanyBecks
# 18    SteffieHorcrux       0   10         0   FrederikeGaal     ShirleyTemple
# 19      YuleHoffnung       0   10         0       ZoeJutter  AmandaFredericks
# 22         ZoeJutter       0   10         0    YuleHoffnung         SallyBrot
# 24        LeoJackson       1   10         0     JohnnyCedar          MaxJovus
# 30          ArnoKrys       1   10         0     VictorSalat        LeoJackson
# 38         MollyMeer       0   11         0      MillyMucks      BettyAllison
# 40        MillyMucks       0   10         0     KatrinGreat         SandraNox
# 44         AlexaNymm       0   10         0       StacyNymm          VeraNyoa
# 45         StacyNymm       0   11         0  SteffieHorcrux      MathildaDamm
# 46          VeraNyoa       0   10         0       AlexaNymm        NancyClick
# 50        BettyOlive       0   10         0     AnnaKruller       VivianKratz
# 52     GeorgiaPammen       0   10         0       AmoraPeer            Pillow
# 61         DavePulps       1   11         0   NewtScamander          ArnoKrys
# 62         IndiPyrre       1   10         0        ArnoKrys         DavePulps
# 65        RobinRacks       0   10         0      AmelieReid         TheaRekle
#
#     Clusters
# 0          2
# 2          2
# 3          2
# 10         2
# 18         2
# 19         2
# 22         2
# 24         2
# 30         2
# 38         2
# 40         2
# 44         2
# 45         2
# 46         2
# 50         2
# 52         2
# 61         2
# 62         2
# 65         2

# %%
def split_dataframes(clustered_list, splits):
    dataframes_split = []
    for i in clustered_list: 
        index_to_split = (-(-len(i)//splits))
        start = 0
        end = index_to_split
        for split in range(splits):
            temporary_df = i.iloc[start:end, :]
            dataframes_split.append(temporary_df)
            start += index_to_split
            end += index_to_split
    return dataframes_split

split_clustered_dataframes = split_dataframes(clustered_dataframes, 4)
split_clustered_dataframes[0]
# Out:
#                 Name  Gender  Age  District       Friend 1       Friend 2  \
# 0       BettyAllison       0   10         0      MollyMeer   JessicaZebra
# 2      GregorAllmann       1   11         0     BertEdamer    CeasarFeige
# 3       TiffanyBecks       0   10         0       AllyInka      SallyBrot
# 10  AmandaFredericks       0   11         0     NancyClick   TiffanyBecks
# 18    SteffieHorcrux       0   10         0  FrederikeGaal  ShirleyTemple
#
#     Clusters
# 0          2
# 2          2
# 3          2
# 10         2
# 18         2

# %%
"""
Splits in split_dataframes_by_position has to be the same as splits in create_diverse_dataframes!
"""

def create_diverse_dataframes(split_list, splits):
    dataframes_diverse = []
    start = 0
    for split in range(splits):        
        if start <= splits - 1:
            new_dataframe_as_list = split_list[start::splits]
            new_dataframe = pd.concat(new_dataframe_as_list)
            dataframes_diverse.append(new_dataframe)
            start += 1
    return dataframes_diverse    
    
diverse_groups = create_diverse_dataframes(split_clustered_dataframes, 5)
diverse_groups[0].head(15)
# Out:
#                 Name  Gender  Age  District        Friend 1       Friend 2  \
# 0       BettyAllison       0   10         0       MollyMeer   JessicaZebra
# 2      GregorAllmann       1   11         0      BertEdamer    CeasarFeige
# 3       TiffanyBecks       0   10         0        AllyInka      SallyBrot
# 10  AmandaFredericks       0   11         0      NancyClick   TiffanyBecks
# 18    SteffieHorcrux       0   10         0   FrederikeGaal  ShirleyTemple
# 25          HankKalt       1   10         3        BasOffen       ColeMaas
# 26           MaxKaal       1   11         3  AlexanderOdele    BillyNozzle
# 27        TrevorKehl       1   10         2        HankKalt       ColeMaas
# 35          ColeMaas       1   10         3     CarlosVives       BasOffen
# 54         AmoraPeer       0   11         3   GeorgiaPammen    VivianKratz
# 67        AmelieReid       0   10         3       TheaRekle      AmoraPeer
# 68         TheaRekle       0   10         3      AmelieReid      AmoraPeer
# 64      SteveQuarter       1   10         1   NewtScamander     WolterPlop
# 70        FrankRingo       1   10         1     G�ntherCohl       ZackOber
#
#     Clusters
# 0          2
# 2          2
# 3          2
# 10         2
# 18         2
# 25         4
# 26         4
# 27         4
# 35         4
# 54         0
# 67         0
# 68         0
# 64         3
# 70         3

# %% [markdown]
# ## Visualising diverse groups

# %%
group = diverse_groups[0]
#sns.scatterplot(data = group, x = "Income", y = "Spending Score", hue = "Clusters", palette = "Set2")

# %%
for group_temp in diverse_groups:
    print(group_temp["Clusters"].value_counts())
    print(len(group_temp))
# Out:
# 2    5
# 4    4
# 0    3
# 3    2
# Name: Clusters, dtype: int64
# 14
# 1    5
# 2    5
# 4    4
# 0    2
# Name: Clusters, dtype: int64
# 16
# 1    5
# 2    5
# 3    5
# 4    3
# Name: Clusters, dtype: int64
# 18
# 1    5
# 3    5
# 2    4
# 0    3
# Name: Clusters, dtype: int64
# 17
# 3    5
# 4    4
# 0    3
# 1    3
# Name: Clusters, dtype: int64
# 15

# %% [markdown]
# Problem: Groups are too different in size!

# %% [markdown]
# ## Creating diverse customer groups (different approach)

# %%
def sort_dataframe(df):
    df["Clusters"] = pd.Categorical(df["Clusters"], [0, 1, 2, 3, 4])
    sorted_dataframe = df.sort_values("Clusters")
    return sorted_dataframe

sort_dataframe(df1).head()
# Out:
#             Name  Gender  Age  District       Friend 1       Friend 2 Clusters
# 8   MathildaDamm       0   10         2   YuleHoffnung      ZoeJutter        0
# 77   JessieSnape       0   10         2   MathildaDamm  StefanieFluss        0
# 54     AmoraPeer       0   11         3  GeorgiaPammen    VivianKratz        0
# 67    AmelieReid       0   10         3      TheaRekle      AmoraPeer        0
# 4      SallyBrot       0   10         2   TiffanyBecks   BettyAllison        0

# %% [markdown]
# ## Keeping two customers together: merging rows before clustering

# %%
df2 = df1.drop("Clusters", axis=1)

def merge_customers1(df, id1, id2):
    customer1 = df[df["CustomerID"] == id1]
    customer2 = df[df["CustomerID"] == id2]
    customer_id = [customer1.iloc[0,0], customer2.iloc[0,0]]
    average_age = (customer1.iloc[0,2] + customer2.iloc[0,2])/2
    average_income = (customer1.iloc[0,3] + customer2.iloc[0,3])/2
    average_spending_score = (customer1.iloc[0,4] + customer2.iloc[0,4])/2
    gender = [customer1.iloc[0,1], customer2.iloc[0,1]]
    merged_c = pd.DataFrame({"CustomerID": [customer_id],
                                      "Gender": [gender],
                                      "Age": [average_age],
                                      "Income": [average_income],
                                      "Spending Score": [average_spending_score]})
    return merged_c


#merge_customers1(df2, 1, 2)

# %%
def merge_customers2(df, id1, id2):
    customer1 = df[df["CustomerID"] == id1]
    customer2 = df[df["CustomerID"] == id2]
    customer_id = [customer1.iloc[0,0], customer2.iloc[0,0]]
    age = [customer1.iloc[0,2], customer2.iloc[0,2]]
    income = [customer1.iloc[0,3], customer2.iloc[0,3]]
    spending_score = [customer1.iloc[0,4], customer2.iloc[0,4]]
    gender = [customer1.iloc[0,1], customer2.iloc[0,1]]
    merged_c = pd.DataFrame({"CustomerID": [customer_id],
                                      "Gender": [gender],
                                      "Age": [age],
                                      "Income": [income],
                                      "Spending Score": [spending_score]})
    return merged_c


#merge_customers2(df2, 1, 200)

# %%
df4 = pd.DataFrame()
#for number in range(1, 101):
    #df_temp = df4.append(merge_customers1(df2, number, 100+number))
    #df4 = df_temp
print(df4)
print(len(df4))
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# 0

# %%
#sns.pairplot(df4[["Age", "Income", "Spending Score"]])

# %% [markdown]
# ## Clustering students based on network communities

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def read_csv():
    df = pd.read_csv("new_df_friends_classes_small.csv", index_col=[0])
    return df

#orig_df = read_csv()
#len(orig_df)

# %%
# visualise network of paired students

import networkx as nx

G_symmetric = nx.Graph()

for index, row in orig_df.iterrows():
    G_symmetric.add_edge(row["id"], row["friend1"])
    G_symmetric.add_edge(row["id"], row["friend2"])

nx.random_layout(G_symmetric)
nx.draw_networkx(G_symmetric, node_size = 25, with_labels = False)

# %%
# extract communities of students and add to list

import networkx as nx
from networkx.algorithms.community import greedy_modularity_communities

def extract_comm(res_number):
    orig_df = read_csv()
    G_symmetric = nx.Graph()
    for index, row in orig_df.iterrows():
        G_symmetric.add_edge(row["id"], row["friend1"])
        G_symmetric.add_edge(row["id"], row["friend2"])
    c = list(greedy_modularity_communities(G_symmetric, resolution = res_number))
    return c

d = extract_comm(1)

print(len(sorted(d[0])))
print(sorted(d[3]))

# check number of items in list, problem : new nodes are created
x = 0
for e in d:
    for i in e:
        x += 1
print(x)
# Out:
# 7
# [5, 18, 36, 82, 89, 114]
# 120

# %%
# check percentage of wishes granted

id1 = list(orig_df["id"])
id2 = list(orig_df["friend1"])
id3 = list(orig_df["friend2"])

ideal_groups = [*map(list, zip(id1, id2, id3))]

x = 0

for community in d:
    for group in ideal_groups:    
        if(set(group).issubset(set(community))):
            x += 1

print(x)
print(x / len(ideal_groups) * 100)
# Out:
# 120
# 100.0

# %%
# turn each community of students into one row in dataframe

def merge_students(res):
    df = read_csv()
    list_sets = extract_comm(res) # resolution set here
    list_df = []
    for set_students in list_sets:
        mask = df["id"].isin(set_students)
        df_set = df.loc[mask]
        temp_df = pd.DataFrame({"id": [set_students],
                                "number_students": [len(set_students)],
                                "gender_int": [round(df_set["gender_int"].mean(), 1)],
                                "color_int": [round(df_set["color_int"].mean(), 1)],
                                "reading_int": [round(df_set["reading_int"].mean(), 1)],
                                "hobby_int": [round(df_set["hobby_int"].mean(), 1)],
                                "language_int": [round(df_set["language_int"].mean(), 1)],
                                "introverted_int": [round(df_set["introverted_int"].mean(), 1)],
                                "siblings": [round(df_set["siblings"].mean(), 1)],
                                "previous_class_int": [round(df_set["previous_class_int"].mean(), 1)]})
        list_df.append(temp_df)
    merged_communities = pd.concat(list_df, ignore_index=True)
    return merged_communities
        
#df_merged_students = merge_students(1)
#df_merged_students.head()

# %% [markdown]
# ## k-means clustering of student groups

# %%
# find ideal number of clusters for k-means clustering

from sklearn.cluster import KMeans
from sklearn import metrics
from scipy.spatial.distance import cdist
import sklearn.cluster as cluster


list_inertia = []

for i in range(2, 11):
    
    model=KMeans(n_clusters=i, random_state=42)
    model.fit(df_merged_students[["gender_int", "color_int", "reading_int", "hobby_int", "language_int", 
                                  "introverted_int", "siblings", "previous_class_int"]])
    
    list_inertia.append(model.inertia_)

plt.plot(range(2,11), list_inertia, 'o--')
plt.xlabel('number of clusters')
plt.ylabel('Sum of Squared Distances')
# Out:
# Text(0, 0.5, 'Sum of Squared Distances')

# %%
# make sklearn pipeline

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

def cluster(df):
    scaler = StandardScaler()
    k = 4
    kmeans = KMeans(n_clusters=k)
    pipeline = make_pipeline(scaler,kmeans)
    pipeline.fit(df[["gender_int", "color_int", "reading_int", "hobby_int", "language_int",
                                 "introverted_int", "siblings", "previous_class_int"]])
    labels = pipeline.predict(df[["gender_int", "color_int", "reading_int", "hobby_int", "language_int", 
                                              "introverted_int", "siblings", "previous_class_int"]])
    df["clusters"] = kmeans.labels_
    return df

#clustered_df = cluster(df_merged_students)
#clustered_df.head()

# %%
# make one dataframe for each cluster and add to list

def list_clustered_dataframes(df):
    dataframes_list = []
    for i in df.clusters.unique():
        temporary_df = df[df["clusters"] == i].reset_index(drop=True)
        dataframes_list.append(temporary_df)
        list_sorted = sorted(dataframes_list, key=len, reverse=True)
    return list_sorted

#list_df_clustered = list_clustered_dataframes(clustered_df)
#list_df_clustered[2]

# %% [markdown]
# ## Forming final classes

# %%
# turn clustered ids into two-dimensional list

def convert_ids(lst):
    ids_clustered = []
    for df in lst:
        ids_clustered.append(df["id"].tolist())
    return ids_clustered

#ids_clustered = convert_ids(list_df_clustered)
#ids_clustered

# %%
import copy

def form_classes(lst_ids_clustered, number_classes):
    ids_clustered_new = copy.deepcopy(lst_ids_clustered)
    length = len(read_csv())
    max_size = length // number_classes
    ids_classes = []
    for number in range(number_classes):
        ids_classes.append([]) # append an empty list for every class to overall list
    for every_class in ids_classes:
        size = 0
        while size < max_size:
            for lst in ids_clustered_new: # go through the clusters within list of IDs/groups of students
                if len(lst[0]) <= max_size - size: # take group of students from cluster if not too big
                    every_class.append(lst[0]) # add group to class
                    size += len(lst[0]) # change remaining class size
                    del lst[0] # delete group of students from cluster
                    if lst == []:
                        ids_clustered_new.remove(lst) # delete cluster if empty
                else:
                    size = max_size
    return ids_classes, ids_clustered_new

#a, b = form_classes(ids_clustered, 7)
#print(a)
#print(b)

# %%
# original set still intact
ids_clustered
# Out:
# [[frozenset({2, 57, 61, 64, 81, 93, 109}),
#   frozenset({5, 18, 36, 82, 89, 114}),
#   frozenset({23, 24, 71, 79, 92, 108}),
#   frozenset({44, 49, 78, 98, 118}),
#   frozenset({21, 38, 106, 107}),
#   frozenset({1, 28, 56, 112}),
#   frozenset({22, 53, 88}),
#   frozenset({17, 111}),
#   frozenset({97, 113}),
#   frozenset({46, 63})],
#  [frozenset({8, 26, 37, 74, 80, 86, 115}),
#   frozenset({7, 15, 41, 48, 55, 65, 66}),
#   frozenset({0, 11, 13, 29, 96, 99}),
#   frozenset({9, 25, 72, 84, 87}),
#   frozenset({31, 54, 58, 91, 104}),
#   frozenset({34, 90, 94, 95}),
#   frozenset({3, 4, 6, 101}),
#   frozenset({14, 19, 20}),
#   frozenset({35, 73, 119}),
#   frozenset({16, 43, 45})],
#  [frozenset({30, 60, 68, 76, 83, 102}),
#   frozenset({51, 62, 75}),
#   frozenset({10, 39, 103}),
#   frozenset({42, 52, 69}),
#   frozenset({59, 85})],
#  [frozenset({33, 47, 77, 105, 117}),
#   frozenset({12, 32, 110}),
#   frozenset({40, 50, 100}),
#   frozenset({27, 67}),
#   frozenset({70, 116})]]

# %%
# convert frozenset1 to 2d list

def convert_set_to_list1(st):
    new_lst = []
    for i in st:
        temp_lst = []
        for e in i:
            for j in e:
                temp_lst.append(j)
        new_lst.append(temp_lst)
    return new_lst

#c = convert_set_to_list1(a)
#c

# %%
# convert frozenset2 to 2d list

def convert_set_to_list2(st):
    new_lst = []
    for i in st:
        for e in i:
            temp_lst = []
            for j in e:
                temp_lst.append(j)
            new_lst.append(temp_lst)
    return new_lst

#d = convert_set_to_list2(b)
#sorted(d, key=len)

#smallest = d.index(min(total_list, key=len))

# %%
def convert_frozensets(a, b):
    c = convert_set_to_list1(a)
    d = convert_set_to_list2(b)
    return c,d

#list1, list2 = convert_frozensets(a, b)

# %%
# adding remaining students
    
def add_rest1(lst_classes, lst_rest):
    merged_list = []
    list1 = sorted(lst_classes, key=len)
    list2 = sorted(lst_rest, key=len, reverse=True)
    for i in range(max((len(list1), len(list2)))):
          while True:
            try:
                list3 = [list1[i], list2[i]]
            except IndexError:
                if len(list1) > len(list2):
                    list2.append([])
                    list3 = [list1[i], list2[i]]
                elif len(list1) < len(list2):
                    list1.append([])
                    list3 = [list1[i], list2[i]]
                continue  
            merged_list.append(list3)
            break
    merged_list_cleaned = []
    for i in merged_list:
        list4 = [] 
        for e in i:            
            for j in e:
                list4.append(j)
        merged_list_cleaned.append(list4)            
    return merged_list_cleaned


#final_classes1 = add_rest1(list1,list2)
#final_classes1

# %%
def add_rest2(cleaned_lst_classes1, number_classes):
    merged_list = []
    list1 = sorted(cleaned_lst_classes1[:number_classes], key = len)
    list2 = sorted(cleaned_lst_classes1[number_classes:], key = len, reverse = True)
    for i in range(max((len(list1), len(list2)))):
          while True:
            try:
                list3 = [list1[i], list2[i]]
            except IndexError:
                if len(list1) > len(list2):
                    list2.append([])
                    list3 = [list1[i], list2[i]]
                elif len(list1) < len(list2):
                    list1.append([])
                    list3 = [list1[i], list2[i]]
                continue  
            merged_list.append(list3)
            break
    merged_list_cleaned = []
    for i in merged_list:
        list4 = [] 
        for e in i:            
            for j in e:
                list4.append(j)
        merged_list_cleaned.append(list4)            
    return merged_list_cleaned

#final_classes2 = add_rest2(final_classes1, 7)
#final_classes2

# %%
# check number of students in final classes

for e in final_classes2:
    x = 0
    for i in e:
        x += 1
    print(x)
# Out:
# 15
# 16
# 16
# 17
# 18
# 19
# 19

# %%
def make_final_dfs(first_df, list_final_classes):
    list_dfs = []
    for e in list_final_classes:
        new_df = first_df[first_df["id"].isin(e)]
        list_dfs.append(new_df)
    return list_dfs

#list_final_dfs = make_final_dfs(read_csv(), final_classes2)

# %%
def get_csv_files(list_dfs):
    x = 0
    for i in list_dfs:
        x += 1
        out_filename = "class" + str(x) + ".csv"
        i.to_csv(out_filename, index = True)

#get_csv_files(d)

# %% [markdown]
# ### some tests done by Jonas

# %%
# copy class df with class information

lst_final_df = []
x = 0

for df in d:
    x += 1
    class_df = df.copy()
    class_df["class"] = x
    lst_final_df.append(class_df)

final_df = pd.concat(lst_final_df)
final_df.reset_index(drop=True, inplace=True)
final_df
# Out:
#       id  previous_class_int  color_int  gender_int  reading_int  hobby_int  \
# 0     28                   1          1           0            0          3
# 1     78                   1          4           0            3          2
# 2     97                   1          1           0            1          1
# 3    100                   1          4           0            2          1
# 4     22                   2          1           1            3          2
# ..   ...                 ...        ...         ...          ...        ...
# 115  114                  11          5           1            3          1
# 116    5                  12          3           1            2          4
# 117   25                  12          3           1            0          2
# 118   86                  12          0           1            1          3
# 119  110                  12          4           1            2          2
#
#      language_int  introverted_int  siblings  friend1  friend2  class
# 0               1                0         3       28      100      1
# 1               0                0         2       28       28      1
# 2               0                0         1      100       28      1
# 3               3                0         1       28       28      1
# 4               4                0         1       77       77      1
# ..            ...              ...       ...      ...      ...    ...
# 115             1                0         0       74       74      5
# 116             3                1         2      110       86      5
# 117             1                1         4       86       86      5
# 118             0                0         4      110      110      5
# 119             2                0         1       86       86      5
#
# [120 rows x 12 columns]

# %%
# loop append cluster dfs to large df for all students
original_df = list_sorted[0].append([list_sorted[1], list_sorted[2], list_sorted[3]])
original_df.reset_index(drop=True, inplace=True)
original_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-fec1838e0de5> in <module>
#       1 # loop append cluster dfs to large df for all students
# ----> 2 original_df = list_sorted[0].append([list_sorted[1], list_sorted[2], list_sorted[3]])
#       3 original_df.reset_index(drop=True, inplace=True)
#       4 original_df
#
# NameError: name 'list_sorted' is not defined

# %%
original_df = cluster(df_merged_students)
exp_original_df = original_df.explode("id")
exp_original_df
# Out:
#      id  number_students  gender_int  color_int  reading_int  hobby_int  \
# 0    64                7         1.0        2.3          1.9        1.7
# 0    81                7         1.0        2.3          1.9        1.7
# 0     2                7         1.0        2.3          1.9        1.7
# 0    93                7         1.0        2.3          1.9        1.7
# 0   109                7         1.0        2.3          1.9        1.7
# ..  ...              ...         ...        ...          ...        ...
# 27   70                2         0.0        0.5          0.5        2.5
# 28   46                2         0.0        1.0          2.5        2.5
# 28   63                2         0.0        1.0          2.5        2.5
# 29   59                2         0.0        4.5          0.5        4.0
# 29   85                2         0.0        4.5          0.5        4.0
#
#     language_int  introverted_int  siblings  previous_class_int  clusters
# 0            1.7              0.7       1.1                10.0         0
# 0            1.7              0.7       1.1                10.0         0
# 0            1.7              0.7       1.1                10.0         0
# 0            1.7              0.7       1.1                10.0         0
# 0            1.7              0.7       1.1                10.0         0
# ..           ...              ...       ...                 ...       ...
# 27           2.0              1.0       1.0                 4.0         3
# 28           1.5              0.0       0.0                 7.0         0
# 28           1.5              0.0       0.0                 7.0         0
# 29           2.0              0.5       0.5                 9.0         3
# 29           2.0              0.5       0.5                 9.0         3
#
# [120 rows x 11 columns]

# %%
# expand list so every student is a row with cluster
expanded_original_df = original_df.explode("id")
expanded_original_df
# Out:
#     id  number_students  gender_int  color_int  reading_int  hobby_int  \
# 0   18                5         0.0        3.2          2.0        1.8
# 0   23                5         0.0        3.2          2.0        1.8
# 0    8                5         0.0        3.2          2.0        1.8
# 0   45                5         0.0        3.2          2.0        1.8
# 0   46                5         0.0        3.2          2.0        1.8
# ..  ..              ...         ...        ...          ...        ...
# 29  17                4         0.0        4.8          0.0        3.2
# 29  58                4         0.0        4.8          0.0        3.2
# 29  14                4         0.0        4.8          0.0        3.2
# 29  39                4         0.0        4.8          0.0        3.2
# 30  20                1         0.0        5.0          0.0        3.0
#
#     language_int  introverted_int  siblings  previous_class_int  clusters
# 0            2.0              0.6       2.0                 4.0         0
# 0            2.0              0.6       2.0                 4.0         0
# 0            2.0              0.6       2.0                 4.0         0
# 0            2.0              0.6       2.0                 4.0         0
# 0            2.0              0.6       2.0                 4.0         0
# ..           ...              ...       ...                 ...       ...
# 29           1.0              0.5       2.8                 9.0         3
# 29           1.0              0.5       2.8                 9.0         3
# 29           1.0              0.5       2.8                 9.0         3
# 29           1.0              0.5       2.8                 9.0         3
# 30           0.0              0.0       3.0                11.0         3
#
# [120 rows x 11 columns]

# %%
# merge expanded_original_df with final dfs
final_merged_df = final_df.merge(expanded_original_df[["id", "clusters"]], how="left", on="id")
final_merged_df
# Out:
#       id  previous_class_int  color_int  gender_int  reading_int  hobby_int  \
# 0     28                   1          1           0            0          3
# 1     78                   1          4           0            3          2
# 2     97                   1          1           0            1          1
# 3    100                   1          4           0            2          1
# 4     22                   2          1           1            3          2
# ..   ...                 ...        ...         ...          ...        ...
# 115  114                  11          5           1            3          1
# 116    5                  12          3           1            2          4
# 117   25                  12          3           1            0          2
# 118   86                  12          0           1            1          3
# 119  110                  12          4           1            2          2
#
#      language_int  introverted_int  siblings  friend1  friend2  class  \
# 0               1                0         3       28      100      1
# 1               0                0         2       28       28      1
# 2               0                0         1      100       28      1
# 3               3                0         1       28       28      1
# 4               4                0         1       77       77      1
# ..            ...              ...       ...      ...      ...    ...
# 115             1                0         0       74       74      5
# 116             3                1         2      110       86      5
# 117             1                1         4       86       86      5
# 118             0                0         4      110      110      5
# 119             2                0         1       86       86      5
#
#      clusters
# 0           0
# 1           0
# 2           0
# 3           0
# 4           2
# ..        ...
# 115         0
# 116         1
# 117         1
# 118         1
# 119         1
#
# [120 rows x 13 columns]

# %%
def final_df_merged(list_final_dfs):
    new_list = []
    x = 0
    for df in list_final_dfs:
        x += 1
        class_df = df.copy()
        class_df["class"] = x
        new_list.append(class_df)
    final_df = pd.concat(new_list)
    final_df.reset_index(drop=True, inplace=True)
    original_df = cluster(df_merged_students)
    exp_original_df = original_df.explode("id")
    final_merged_df = final_df.merge(exp_original_df[["id", "clusters"]], how="left", on="id")
    return final_merged_df

#merged_df = final_df_merged(list_final_dfs)
#merged_df

# %%
temp_df = final_merged_df[final_merged_df["class"]==1]
temp_df.head()
# Out:
#    id  previous_class_int  color_int  gender_int  reading_int  hobby_int  \
# 0  23                   6          2           1            3          2
# 1  24                   6          0           1            0          2
# 2  71                   6          0           1            0          3
# 3  79                   6          5           1            3          0
# 4  92                   6          1           1            0          1
#
#    language_int  introverted_int  siblings  friend1  friend2  class  clusters
# 0             2                1         0      108      108      1         2
# 1             2                0         0       24       71      1         2
# 2             0                1         0       92       24      1         2
# 3             2                1         0       23      108      1         2
# 4             4                0         4      108       23      1         2

# %%
# check if friend 1 is in class and calculate share of True
# TODO: maybe add a check for friend 2 when friend 1 wasn't found

# Wish score much lower than before - maybe different when we check for friend2?

def measure_wishs_granted(df):
    friend1_found = df["friend1"].isin(df["id"]).value_counts(normalize=True).reset_index()
    friend1_found.columns = ["friend1_found", "share"]
    wish_score1 = round(friend1_found.loc[friend1_found["friend1_found"]==True, "share"].values[0],2)
    
    friend2_found = df["friend2"].isin(df["id"]).value_counts(normalize=True).reset_index()
    friend2_found.columns = ["friend2_found", "share"]
    wish_score2 = round(friend2_found.loc[friend2_found["friend2_found"]==True, "share"].values[0],2)
    
    overall_wish_score = round((wish_score1 + wish_score2) / 2, 2)
    
    return overall_wish_score

# %%
# calculate median cluster share
# ideal: 1 / number of clusters (e.g., in case of four clusters the median should be 25%)
# Does this still apply when distribution of students is not 25% per cluster? So, when 50% of students are in cluster 0?

def measure_diversity(df, nb_clusters):
    
    # calculate ideal score
    ideal_score = 1/nb_clusters

    # calculate score for current class
    cluster_distribution = df["clusters"].value_counts(normalize=True).reset_index()
    cluster_distribution.columns = ["cluster", "share"]
    diversity_score = round(cluster_distribution["share"].median(),2) * nb_clusters # perfect split will turn to 1.0
    
    return diversity_score

# %%
# evaluate how well the final class is in terms of diversity and wishs granted

def quality_check(final_merged_df):
    for current_class in pd.unique(final_merged_df["class"]):    
        temp_df = final_merged_df[final_merged_df["class"]==current_class]
        diversity_score = measure_diversity(temp_df, 4)    
        wish_score = measure_wishs_granted(temp_df)    
        print(f"Class {current_class} has a diversity score of {diversity_score} and a wish score of {wish_score}.")

#quality_check(merged_df)

# %%
# Class 5 has the worst diversity score. Why? Only three clusters
df = final_merged_df[final_merged_df["class"]==5]
cluster_distribution = df["clusters"].value_counts(normalize=True).reset_index()
cluster_distribution.columns = ["cluster", "share"]
cluster_distribution
# Out:
#    cluster  share
# 0        1  0.500
# 1        0  0.375
# 2        2  0.125

# %%
# Diversity distribution for class 3
df = final_merged_df[final_merged_df["class"]==3]
cluster_distribution = df["clusters"].value_counts(normalize=True).reset_index()
cluster_distribution.columns = ["cluster", "share"]
cluster_distribution
# Out:
#    cluster     share
# 0        1  0.375000
# 1        2  0.250000
# 2        0  0.208333
# 3        3  0.166667

# %%
def main(number_classes, res): # number of classes and resolution

    for i in range(res):
        
        # merging students 
        
        df_merged_students = merge_students(res)
        
        # clustering
        
        clustered_df = cluster(df_merged_students)
        list_df_clustered = list_clustered_dataframes(clustered_df)
        ids_clustered = convert_ids(list_df_clustered)
        
        # class formation
        
        a, b = form_classes(ids_clustered, number_classes)
        list1, list2 = convert_frozensets(a, b)
        final_classes1 = add_rest1(list1,list2)
        final_classes2 = add_rest2(final_classes1, number_classes)
        list_final_dfs = make_final_dfs(read_csv(), final_classes2)

        # test quality

        final_df = final_df_merged(list_final_dfs)
        check = quality_check(final_df)
        print(check)
    
main(6, 10)
# Out:
# Class 1 has a diversity score of 1.32 and a wish score of 0.97.
# Class 2 has a diversity score of 1.0 and a wish score of 0.98.
# Class 3 has a diversity score of 1.12 and a wish score of 0.98.
# Class 4 has a diversity score of 0.48 and a wish score of 0.95.
# Class 5 has a diversity score of 0.96 and a wish score of 1.0.
# Class 6 has a diversity score of 0.84 and a wish score of 0.98.
# None
# Class 1 has a diversity score of 2.0 and a wish score of 0.95.
# Class 2 has a diversity score of 1.6 and a wish score of 0.98.
# Class 3 has a diversity score of 2.0 and a wish score of 0.95.
# Class 4 has a diversity score of 1.2 and a wish score of 1.0.
# Class 5 has a diversity score of 1.6 and a wish score of 0.98.
# Class 6 has a diversity score of 1.32 and a wish score of 1.0.
# None
# Class 1 has a diversity score of 1.48 and a wish score of 0.98.
# Class 2 has a diversity score of 1.4 and a wish score of 0.98.
# Class 3 has a diversity score of 1.2 and a wish score of 0.98.
# Class 4 has a diversity score of 2.0 and a wish score of 0.98.
# Class 5 has a diversity score of 1.6 and a wish score of 0.98.
# Class 6 has a diversity score of 1.16 and a wish score of 0.98.
# None
# Class 1 has a diversity score of 1.28 and a wish score of 1.0.
# Class 2 has a diversity score of 0.8 and a wish score of 0.95.
# Class 3 has a diversity score of 1.0 and a wish score of 0.98.
# Class 4 has a diversity score of 0.92 and a wish score of 1.0.
# Class 5 has a diversity score of 1.4 and a wish score of 0.95.
# Class 6 has a diversity score of 1.32 and a wish score of 0.98.
# None
# Class 1 has a diversity score of 1.12 and a wish score of 1.0.
# Class 2 has a diversity score of 2.0 and a wish score of 0.98.
# Class 3 has a diversity score of 1.2 and a wish score of 0.95.
# Class 4 has a diversity score of 1.0 and a wish score of 0.95.
# Class 5 has a diversity score of 0.48 and a wish score of 1.0.
# Class 6 has a diversity score of 1.16 and a wish score of 0.98.
# None
# Class 1 has a diversity score of 1.16 and a wish score of 1.0.
# Class 2 has a diversity score of 2.0 and a wish score of 0.98.
# Class 3 has a diversity score of 0.88 and a wish score of 0.98.
# Class 4 has a diversity score of 0.76 and a wish score of 1.0.
# Class 5 has a diversity score of 1.16 and a wish score of 1.0.
# Class 6 has a diversity score of 1.52 and a wish score of 0.95.
# None
# Class 1 has a diversity score of 1.32 and a wish score of 0.97.
# Class 2 has a diversity score of 1.0 and a wish score of 1.0.
# Class 3 has a diversity score of 0.8 and a wish score of 0.98.
# Class 4 has a diversity score of 1.4 and a wish score of 1.0.
# Class 5 has a diversity score of 1.32 and a wish score of 1.0.
# Class 6 has a diversity score of 1.04 and a wish score of 0.9.
# None
# Class 1 has a diversity score of 1.32 and a wish score of 1.0.
# Class 2 has a diversity score of 2.0 and a wish score of 0.97.
# Class 3 has a diversity score of 1.2 and a wish score of 0.98.
# Class 4 has a diversity score of 0.84 and a wish score of 0.95.
# Class 5 has a diversity score of 2.0 and a wish score of 0.98.
# Class 6 has a diversity score of 1.08 and a wish score of 1.0.
# None
# Class 1 has a diversity score of 1.48 and a wish score of 0.98.
# Class 2 has a diversity score of 1.0 and a wish score of 0.98.
# Class 3 has a diversity score of 1.0 and a wish score of 1.0.
# Class 4 has a diversity score of 1.12 and a wish score of 0.95.
# Class 5 has a diversity score of 1.2 and a wish score of 1.0.
# Class 6 has a diversity score of 0.96 and a wish score of 1.0.
# None
# Class 1 has a diversity score of 2.0 and a wish score of 1.0.
# Class 2 has a diversity score of 0.8 and a wish score of 0.98.
# Class 3 has a diversity score of 1.0 and a wish score of 0.95.
# Class 4 has a diversity score of 1.0 and a wish score of 0.98.
# Class 5 has a diversity score of 2.0 and a wish score of 0.98.
# Class 6 has a diversity score of 1.32 and a wish score of 0.98.
# None
