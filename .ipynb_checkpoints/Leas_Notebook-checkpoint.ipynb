# %% [markdown]
# # K-means clustering

# %% [markdown]
# ## Exploratory data analysis: mall customer segmentation data (kaggle)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

df1 = pd.read_csv("The Muggle Sorting Hat DataSet.csv")
df1["Gender"] = df1["Gender"].str.replace(" ", "")
df1["District"] = df1["District"].str.replace(" ", "")
df1["Name"] = df1["Name"].str.replace(" ", "")
df1["Friend 1"] = df1["Friend 1"].str.replace(" ", "")
df1["Friend 2 "] = df1["Friend 2 "].str.replace(" ", "")
df1.rename(columns = {"Friend 2 ":"Friend 2"}, inplace = True)
df1.head()
# Out:
#             Name  Gender  Age District      Friend 1      Friend 2
# 0   BettyAllison  female   10  Pandora     MollyMeer  JessicaZebra
# 1     PeterAlexs    male   10    Limsa   G�ntherCohl   CeasarFeige
# 2  GregorAllmann    male   11  Pandora    BertEdamer   CeasarFeige
# 3   TiffanyBecks  female   10  Pandora      AllyInka     SallyBrot
# 4      SallyBrot  female   10    Limsa  TiffanyBecks  BettyAllison

# %%
#df1.rename(columns = {"Annual Income (k$)":"Income", "Spending Score (1-100)":"Spending Score"}, inplace = True)
#df1.head()

# %%
df1.describe()
# Out:
#              Age
# count  80.000000
# mean   10.112500
# std     0.317974
# min    10.000000
# 25%    10.000000
# 50%    10.000000
# 75%    10.000000
# max    11.000000

# %%
sns.pairplot(df1[["Age", "District", "Gender"]])

# %%
df1["District"].value_counts()
# Out:
# Pandora       19
# Uldah         17
# Limsa         15
# Queensdale    11
# Gridania      11
# Reach          7
# Name: District, dtype: int64

# %%
dic = {"Pandora" : "0", "Uldah" : "1", "Limsa" : "2", "Queensdale" : "3", "Gridania" : "4", "Reach" : "5"}
dic2 = {"female" : "0", "male" : "1"}

for old, new in dic.items():
    df1['District'] = df1['District'].str.replace(old, new, regex=False)

for old, new in dic2.items():
    df1['Gender'] = df1['Gender'].str.replace(old, new, regex=False)

df1['District'] = df1['District'].astype(int)
df1['Gender'] = df1['Gender'].astype(int)

# %%
df1.head()
df1["Gender"].value_counts()
# Out:
# 1    41
# 0    39
# Name: Gender, dtype: int64

# %% [markdown]
# ## Clustering mall customer segmentation data

# %%
import sklearn.cluster as cluster
kmeans = cluster.KMeans(n_clusters = 5, init = "k-means++", random_state = 42)
kmeans = kmeans.fit(df1[["District", "Gender"]])
kmeans.cluster_centers_
# Out:
# array([[ 2.54545455e+00, -1.11022302e-16],
#        [ 4.38888889e+00,  5.55555556e-01],
#        [ 0.00000000e+00,  2.63157895e-01],
#        [ 1.00000000e+00,  6.47058824e-01],
#        [ 2.33333333e+00,  1.00000000e+00]])

# %%
df1["Clusters"] = kmeans.labels_
df1.head(10)
# Out:
#             Name  Gender  Age  District      Friend 1          Friend 2  \
# 0   BettyAllison       0   10         0     MollyMeer      JessicaZebra
# 1     PeterAlexs       1   10         2   G�ntherCohl       CeasarFeige
# 2  GregorAllmann       1   11         0    BertEdamer       CeasarFeige
# 3   TiffanyBecks       0   10         0      AllyInka         SallyBrot
# 4      SallyBrot       0   10         2  TiffanyBecks      BettyAllison
# 5     NancyClick       0   11         1     ZoeJutter  AmandaFredericks
# 6    G�ntherCohl       1   10         1   CeasarFeige        PeterAlexs
# 7    JohnnyCedar       1   10         4   MarvinGeige        LeoJackson
# 8   MathildaDamm       0   10         2  YuleHoffnung         ZoeJutter
# 9     BertEdamer       1   10         1    PeterAlexs       G�ntherCohl
#
#    Clusters
# 0         2
# 1         4
# 2         2
# 3         2
# 4         0
# 5         3
# 6         3
# 7         1
# 8         0
# 9         3

# %%
df1["Clusters"].value_counts()
# Out:
# 2    19
# 1    18
# 3    17
# 4    15
# 0    11
# Name: Clusters, dtype: int64

# %%
sns.scatterplot(data = df1, x = "Age", y = "District", hue = "Clusters", palette = "Set2")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='District'>

# %% [markdown]
# ## Creating diverse customer groups

# %%
"""
First function creates list a of clustered dataframes (one df per cluster); second function takes list a,
splits clustered dataframes into required number of diverse groups (splits) and adds them to list b; third function 
combines splitted dataframes in list b into new (diverse) dataframes and adds them to list c.
"""
#from functools import reduce

def create_clustered_dataframes(df):
    dataframes = []
    for i in df.Clusters.unique():
        temporary_df = df[df["Clusters"] == i]
        dataframes.append(temporary_df)
    return dataframes

clustered_dataframes = create_clustered_dataframes(df1)
clustered_dataframes[0]
# Out:
#                 Name  Gender  Age  District        Friend 1          Friend 2  \
# 0       BettyAllison       0   10         0       MollyMeer      JessicaZebra
# 2      GregorAllmann       1   11         0      BertEdamer       CeasarFeige
# 3       TiffanyBecks       0   10         0        AllyInka         SallyBrot
# 10  AmandaFredericks       0   11         0      NancyClick      TiffanyBecks
# 18    SteffieHorcrux       0   10         0   FrederikeGaal     ShirleyTemple
# 19      YuleHoffnung       0   10         0       ZoeJutter  AmandaFredericks
# 22         ZoeJutter       0   10         0    YuleHoffnung         SallyBrot
# 24        LeoJackson       1   10         0     JohnnyCedar          MaxJovus
# 30          ArnoKrys       1   10         0     VictorSalat        LeoJackson
# 38         MollyMeer       0   11         0      MillyMucks      BettyAllison
# 40        MillyMucks       0   10         0     KatrinGreat         SandraNox
# 44         AlexaNymm       0   10         0       StacyNymm          VeraNyoa
# 45         StacyNymm       0   11         0  SteffieHorcrux      MathildaDamm
# 46          VeraNyoa       0   10         0       AlexaNymm        NancyClick
# 50        BettyOlive       0   10         0     AnnaKruller       VivianKratz
# 52     GeorgiaPammen       0   10         0       AmoraPeer            Pillow
# 61         DavePulps       1   11         0   NewtScamander          ArnoKrys
# 62         IndiPyrre       1   10         0        ArnoKrys         DavePulps
# 65        RobinRacks       0   10         0      AmelieReid         TheaRekle
#
#     Clusters
# 0          2
# 2          2
# 3          2
# 10         2
# 18         2
# 19         2
# 22         2
# 24         2
# 30         2
# 38         2
# 40         2
# 44         2
# 45         2
# 46         2
# 50         2
# 52         2
# 61         2
# 62         2
# 65         2

# %%
def split_dataframes(clustered_list, splits):
    dataframes_split = []
    for i in clustered_list: 
        index_to_split = (-(-len(i)//splits))
        start = 0
        end = index_to_split
        for split in range(splits):
            temporary_df = i.iloc[start:end, :]
            dataframes_split.append(temporary_df)
            start += index_to_split
            end += index_to_split
    return dataframes_split

split_clustered_dataframes = split_dataframes(clustered_dataframes, 4)
split_clustered_dataframes[0]
# Out:
#                 Name  Gender  Age  District       Friend 1       Friend 2  \
# 0       BettyAllison       0   10         0      MollyMeer   JessicaZebra
# 2      GregorAllmann       1   11         0     BertEdamer    CeasarFeige
# 3       TiffanyBecks       0   10         0       AllyInka      SallyBrot
# 10  AmandaFredericks       0   11         0     NancyClick   TiffanyBecks
# 18    SteffieHorcrux       0   10         0  FrederikeGaal  ShirleyTemple
#
#     Clusters
# 0          2
# 2          2
# 3          2
# 10         2
# 18         2

# %%
"""
Splits in split_dataframes_by_position has to be the same as splits in create_diverse_dataframes!
"""

def create_diverse_dataframes(split_list, splits):
    dataframes_diverse = []
    start = 0
    for split in range(splits):        
        if start <= splits - 1:
            new_dataframe_as_list = split_list[start::splits]
            new_dataframe = pd.concat(new_dataframe_as_list)
            dataframes_diverse.append(new_dataframe)
            start += 1
    return dataframes_diverse    
    
diverse_groups = create_diverse_dataframes(split_clustered_dataframes, 5)
diverse_groups[0].head(15)
# Out:
#                 Name  Gender  Age  District        Friend 1       Friend 2  \
# 0       BettyAllison       0   10         0       MollyMeer   JessicaZebra
# 2      GregorAllmann       1   11         0      BertEdamer    CeasarFeige
# 3       TiffanyBecks       0   10         0        AllyInka      SallyBrot
# 10  AmandaFredericks       0   11         0      NancyClick   TiffanyBecks
# 18    SteffieHorcrux       0   10         0   FrederikeGaal  ShirleyTemple
# 25          HankKalt       1   10         3        BasOffen       ColeMaas
# 26           MaxKaal       1   11         3  AlexanderOdele    BillyNozzle
# 27        TrevorKehl       1   10         2        HankKalt       ColeMaas
# 35          ColeMaas       1   10         3     CarlosVives       BasOffen
# 54         AmoraPeer       0   11         3   GeorgiaPammen    VivianKratz
# 67        AmelieReid       0   10         3       TheaRekle      AmoraPeer
# 68         TheaRekle       0   10         3      AmelieReid      AmoraPeer
# 64      SteveQuarter       1   10         1   NewtScamander     WolterPlop
# 70        FrankRingo       1   10         1     G�ntherCohl       ZackOber
#
#     Clusters
# 0          2
# 2          2
# 3          2
# 10         2
# 18         2
# 25         4
# 26         4
# 27         4
# 35         4
# 54         0
# 67         0
# 68         0
# 64         3
# 70         3

# %% [markdown]
# ## Visualising diverse groups

# %%
group = diverse_groups[0]
#sns.scatterplot(data = group, x = "Income", y = "Spending Score", hue = "Clusters", palette = "Set2")

# %%
for group_temp in diverse_groups:
    print(group_temp["Clusters"].value_counts())
    print(len(group_temp))
# Out:
# 2    5
# 4    4
# 0    3
# 3    2
# Name: Clusters, dtype: int64
# 14
# 1    5
# 2    5
# 4    4
# 0    2
# Name: Clusters, dtype: int64
# 16
# 1    5
# 2    5
# 3    5
# 4    3
# Name: Clusters, dtype: int64
# 18
# 1    5
# 3    5
# 2    4
# 0    3
# Name: Clusters, dtype: int64
# 17
# 3    5
# 4    4
# 0    3
# 1    3
# Name: Clusters, dtype: int64
# 15

# %% [markdown]
# Problem: Groups are too different in size!

# %% [markdown]
# ## Creating diverse customer groups (different approach)

# %%
def sort_dataframe(df):
    df["Clusters"] = pd.Categorical(df["Clusters"], [0, 1, 2, 3, 4])
    sorted_dataframe = df.sort_values("Clusters")
    return sorted_dataframe

sort_dataframe(df1).head()
# Out:
#             Name  Gender  Age  District       Friend 1       Friend 2 Clusters
# 8   MathildaDamm       0   10         2   YuleHoffnung      ZoeJutter        0
# 77   JessieSnape       0   10         2   MathildaDamm  StefanieFluss        0
# 54     AmoraPeer       0   11         3  GeorgiaPammen    VivianKratz        0
# 67    AmelieReid       0   10         3      TheaRekle      AmoraPeer        0
# 4      SallyBrot       0   10         2   TiffanyBecks   BettyAllison        0

# %% [markdown]
# ## Keeping two customers together: merging rows before clustering

# %%
df2 = df1.drop("Clusters", axis=1)

def merge_customers1(df, id1, id2):
    customer1 = df[df["CustomerID"] == id1]
    customer2 = df[df["CustomerID"] == id2]
    customer_id = [customer1.iloc[0,0], customer2.iloc[0,0]]
    average_age = (customer1.iloc[0,2] + customer2.iloc[0,2])/2
    average_income = (customer1.iloc[0,3] + customer2.iloc[0,3])/2
    average_spending_score = (customer1.iloc[0,4] + customer2.iloc[0,4])/2
    gender = [customer1.iloc[0,1], customer2.iloc[0,1]]
    merged_c = pd.DataFrame({"CustomerID": [customer_id],
                                      "Gender": [gender],
                                      "Age": [average_age],
                                      "Income": [average_income],
                                      "Spending Score": [average_spending_score]})
    return merged_c


#merge_customers1(df2, 1, 2)

# %%
def merge_customers2(df, id1, id2):
    customer1 = df[df["CustomerID"] == id1]
    customer2 = df[df["CustomerID"] == id2]
    customer_id = [customer1.iloc[0,0], customer2.iloc[0,0]]
    age = [customer1.iloc[0,2], customer2.iloc[0,2]]
    income = [customer1.iloc[0,3], customer2.iloc[0,3]]
    spending_score = [customer1.iloc[0,4], customer2.iloc[0,4]]
    gender = [customer1.iloc[0,1], customer2.iloc[0,1]]
    merged_c = pd.DataFrame({"CustomerID": [customer_id],
                                      "Gender": [gender],
                                      "Age": [age],
                                      "Income": [income],
                                      "Spending Score": [spending_score]})
    return merged_c


#merge_customers2(df2, 1, 200)

# %%
df4 = pd.DataFrame()
#for number in range(1, 101):
    #df_temp = df4.append(merge_customers1(df2, number, 100+number))
    #df4 = df_temp
print(df4)
print(len(df4))
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# 0

# %%
#sns.pairplot(df4[["Age", "Income", "Spending Score"]])

# %% [markdown]
# ## Clustering students based on network communities

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
new_df_friends = pd.read_csv("new_df_friends_classes_big.csv", index_col=[0])
new_df_friends.head()
# Out:
#     id  previous_class_int  color_int  gender_int  reading_int  hobby_int  \
# 1    7                   0          0           0            0          0
# 2   34                   0          1           0            1          1
# 4   76                   0          0           0            2          2
# 5  100                   0          2           0            3          2
# 6  106                   0          3           0            3          3
#
#    language_int  introverted_int  siblings  friend1  friend2
# 1             0                0         1       51        0
# 2             1                1         3       51        0
# 4             2                1         1       51       51
# 5             0                1         1        0       51
# 6             3                1         1      100        7

# %%
# visualise network of paired students

import networkx as nx

G_symmetric = nx.Graph()

for index, row in new_df_friends.iterrows():
    G_symmetric.add_edge(row["id"], row["friend1"])
    G_symmetric.add_edge(row["id"], row["friend2"])

nx.random_layout(G_symmetric)
nx.draw_networkx(G_symmetric, node_size = 25, with_labels = False)

# %%
# extract communities of students and add to list

from networkx.algorithms.community import greedy_modularity_communities

c = list(greedy_modularity_communities(G_symmetric, resolution = 16)) # resolution: size of groups/wishes granted

print(len(sorted(c[0])))
print(sorted(c[0]))
# Out:
# 10
# [2, 57, 63, 90, 118, 169, 211, 264, 268, 290]

# %%
# check percentage of wishes granted

id1 = list(new_df_friends["id"])
id2 = list(new_df_friends["friend1"])
id3 = list(new_df_friends["friend2"])

ideal_groups = [*map(list, zip(id1, id2, id3))]

x = 0

for community in c:
    for group in ideal_groups:    
        if(set(group).issubset(set(community))):
            x += 1

print(x)
print(x / len(ideal_groups) * 100)
# Out:
# 181
# 72.39999999999999

# %%
# turn each community of students into one row in dataframe

def merge_students(df, list_sets):
    list_df = []
    for set_students in list_sets:
        mask = df["id"].isin(set_students)
        df_set = df.loc[mask]
        temp_df = pd.DataFrame({"id": [set_students],
                                "number_students": [len(set_students)],
                                "gender_int": [round(df_set["gender_int"].mean(), 1)],
                                "color_int": [round(df_set["color_int"].mean(), 1)],
                                "reading_int": [round(df_set["reading_int"].mean(), 1)],
                                "hobby_int": [round(df_set["hobby_int"].mean(), 1)],
                                "language_int": [round(df_set["language_int"].mean(), 1)],
                                "introverted_int": [round(df_set["introverted_int"].mean(), 1)],
                                "siblings": [round(df_set["siblings"].mean(), 1)],
                                "previous_class_int": [round(df_set["previous_class_int"].mean(), 1)]})
        list_df.append(temp_df)
    merged_communities = pd.concat(list_df, ignore_index=True)
    return merged_communities
        
df_merged_students = merge_students(new_df_friends, c)
df_merged_students.head()
# Out:
#                                               id  number_students  gender_int  \
# 0  (2, 290, 264, 169, 268, 211, 118, 57, 90, 63)               10         0.0
# 1         (0, 34, 100, 7, 106, 76, 236, 178, 51)                9         0.0
# 2       (228, 6, 297, 138, 53, 55, 185, 93, 190)                9         0.0
# 3     (260, 136, 42, 45, 208, 149, 120, 285, 30)                9         1.0
# 4       (39, 71, 173, 174, 19, 117, 25, 282, 27)                9         0.0
#
#    color_int  reading_int  hobby_int  language_int  introverted_int  siblings  \
# 0        2.7          1.7        2.4           2.6              0.4       2.2
# 1        1.6          2.0        1.9           1.4              0.6       1.0
# 2        3.0          0.8        2.1           2.1              0.6       1.9
# 3        2.0          2.0        2.1           1.8              0.8       2.0
# 4        2.5          1.0        2.0           1.9              0.4       1.9
#
#    previous_class_int
# 0                14.0
# 1                 0.0
# 2                 8.0
# 3                12.0
# 4                13.0

# %% [markdown]
# ## k-means clustering of student groups

# %%
# find ideal number of clusters for k-means clustering

from sklearn.cluster import KMeans
from sklearn import metrics
from scipy.spatial.distance import cdist
import sklearn.cluster as cluster


list_inertia = []

for i in range(2, 11):
    
    model=KMeans(n_clusters=i, random_state=42)
    model.fit(df_merged_students[["gender_int", "color_int", "reading_int", "hobby_int", "language_int", 
                                  "introverted_int", "siblings", "previous_class_int"]])
    
    list_inertia.append(model.inertia_)

plt.plot(range(2,11), list_inertia, 'o--')
plt.xlabel('number of clusters')
plt.ylabel('Sum of Squared Distances')
# Out:
# Text(0, 0.5, 'Sum of Squared Distances')

# %%
# make sklearn pipeline

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

scaler = StandardScaler()

k = 5
kmeans = KMeans(n_clusters=k)

pipeline = make_pipeline(scaler,kmeans)
pipeline.fit(df_merged_students[["gender_int", "color_int", "reading_int", "hobby_int", "language_int",
                                 "introverted_int", "siblings", "previous_class_int"]])

labels = pipeline.predict(df_merged_students[["gender_int", "color_int", "reading_int", "hobby_int", "language_int", 
                                              "introverted_int", "siblings", "previous_class_int"]])

# %%
#add clusters to dataframe

df_merged_students["clusters"] = kmeans.labels_
df_merged_students.head()
# Out:
#                                               id  number_students  gender_int  \
# 0  (2, 290, 264, 169, 268, 211, 118, 57, 90, 63)               10         0.0
# 1         (0, 34, 100, 7, 106, 76, 236, 178, 51)                9         0.0
# 2       (228, 6, 297, 138, 53, 55, 185, 93, 190)                9         0.0
# 3     (260, 136, 42, 45, 208, 149, 120, 285, 30)                9         1.0
# 4       (39, 71, 173, 174, 19, 117, 25, 282, 27)                9         0.0
#
#    color_int  reading_int  hobby_int  language_int  introverted_int  siblings  \
# 0        2.7          1.7        2.4           2.6              0.4       2.2
# 1        1.6          2.0        1.9           1.4              0.6       1.0
# 2        3.0          0.8        2.1           2.1              0.6       1.9
# 3        2.0          2.0        2.1           1.8              0.8       2.0
# 4        2.5          1.0        2.0           1.9              0.4       1.9
#
#    previous_class_int  clusters
# 0                14.0         2
# 1                 0.0         3
# 2                 8.0         3
# 3                12.0         4
# 4                13.0         2

# %%
# make one dataframe for each cluster and add to list

def create_clustered_dataframes(df):
    dataframes_list = []
    for i in df.clusters.unique():
        temporary_df = df[df["clusters"] == i].reset_index(drop=True)
        dataframes_list.append(temporary_df)
    return dataframes_list

list_df_clustered = create_clustered_dataframes(df_merged_students)
list_sorted = sorted(list_df_clustered, key=len, reverse=True)
list_sorted[2]
# Out:
#                                       id  number_students  gender_int  \
# 0   (128, 129, 13, 177, 86, 182, 56, 95)                8         1.0
# 1     (224, 81, 258, 273, 245, 125, 157)                7         1.0
# 2     (210, 179, 52, 213, 165, 246, 203)                7         1.0
# 3                (67, 40, 9, 75, 60, 31)                6         1.0
# 4          (130, 148, 196, 219, 61, 110)                6         1.0
# 5          (36, 102, 215, 248, 139, 142)                6         0.0
# 6               (176, 161, 88, 250, 283)                5         1.0
# 7               (32, 274, 295, 298, 189)                5         1.0
# 8                     (192, 65, 166, 23)                4         1.0
# 9                          (1, 186, 132)                3         1.0
# 10                        (249, 202, 47)                3         0.0
# 11                              (77, 79)                2         1.0
# 12                            (244, 231)                2         0.0
#
#     color_int  reading_int  hobby_int  language_int  introverted_int  \
# 0         2.0          1.6        1.8           2.6              0.1
# 1         3.0          0.8        1.8           1.5              0.3
# 2         2.8          0.8        1.3           2.8              0.7
# 3         1.4          1.2        1.6           1.4              0.4
# 4         2.2          0.8        1.0           2.4              0.2
# 5         1.0          0.8        1.8           1.5              0.2
# 6         2.2          1.8        3.0           2.0              0.2
# 7         2.8          1.2        2.0           2.0              0.2
# 8         1.7          1.0        1.3           1.7              0.3
# 9         2.3          1.3        1.0           2.7              0.3
# 10        1.0          1.3        0.3           3.0              0.0
# 11        3.5          0.5        1.5           1.5              0.5
# 12        1.0          2.0        1.0           3.0              0.0
#
#     siblings  previous_class_int  clusters
# 0        2.6                 7.0         1
# 1        1.5                 4.0         1
# 2        2.0                 5.0         1
# 3        2.2                 0.0         1
# 4        0.4                 1.0         1
# 5        3.5                 2.0         1
# 6        2.6                 3.0         1
# 7        1.5                 3.0         1
# 8        1.0                 0.0         1
# 9        1.7                 0.0         1
# 10       2.3                 3.0         1
# 11       3.0                 0.0         1
# 12       1.0                 5.0         1

# %% [markdown]
# ## Forming final classes

# %%
# turn clustered ids into two-dimensional list

ids_clustered = []

for df in list_sorted:
    ids_clustered.append(df["id"].tolist())

ids_clustered
# Out:
# [[frozenset({0, 7, 34, 51, 76, 100, 106, 178, 236}),
#   frozenset({6, 53, 55, 93, 138, 185, 190, 228, 297}),
#   frozenset({22, 80, 133, 170, 204, 222, 241, 253}),
#   frozenset({91, 137, 151, 214, 216, 220, 232}),
#   frozenset({14, 111, 115, 175, 184, 247, 254}),
#   frozenset({15, 84, 107, 143, 160, 233, 235}),
#   frozenset({10, 70, 87, 188, 199, 281, 296}),
#   frozenset({96, 201, 234, 269, 278, 284}),
#   frozenset({4, 68, 69, 72}),
#   frozenset({82, 101, 122, 262}),
#   frozenset({3, 43, 78, 266}),
#   frozenset({64, 225, 259}),
#   frozenset({33, 227})],
#  [frozenset({30, 42, 45, 120, 136, 149, 208, 260, 285}),
#   frozenset({21, 46, 54, 83, 109, 126, 226, 288}),
#   frozenset({11, 24, 155, 238, 251, 263, 276, 287}),
#   frozenset({17, 135, 153, 171, 180, 209, 275, 294}),
#   frozenset({18, 28, 50, 98, 104, 108, 207, 256}),
#   frozenset({12, 16, 134, 152, 154, 193, 237}),
#   frozenset({44, 62, 97, 159, 167, 187, 242}),
#   frozenset({20, 92, 158, 252, 293}),
#   frozenset({172, 194, 217, 286}),
#   frozenset({66, 103, 183, 280}),
#   frozenset({124, 195, 212, 279}),
#   frozenset({58, 140, 267, 299}),
#   frozenset({5, 35, 105})],
#  [frozenset({13, 56, 86, 95, 128, 129, 177, 182}),
#   frozenset({81, 125, 157, 224, 245, 258, 273}),
#   frozenset({52, 165, 179, 203, 210, 213, 246}),
#   frozenset({9, 31, 40, 60, 67, 75}),
#   frozenset({61, 110, 130, 148, 196, 219}),
#   frozenset({36, 102, 139, 142, 215, 248}),
#   frozenset({88, 161, 176, 250, 283}),
#   frozenset({32, 189, 274, 295, 298}),
#   frozenset({23, 65, 166, 192}),
#   frozenset({1, 132, 186}),
#   frozenset({47, 202, 249}),
#   frozenset({77, 79}),
#   frozenset({231, 244})],
#  [frozenset({2, 57, 63, 90, 118, 169, 211, 264, 268, 290}),
#   frozenset({19, 25, 27, 39, 71, 117, 173, 174, 282}),
#   frozenset({85, 112, 147, 191, 218, 261, 265, 270}),
#   frozenset({121, 123, 164, 230, 240, 243}),
#   frozenset({48, 59, 131, 221}),
#   frozenset({113, 239, 291}),
#   frozenset({116, 181})],
#  [frozenset({26, 41, 163, 272, 289, 292}),
#   frozenset({73, 94, 127, 146, 197, 277}),
#   frozenset({8, 29, 38, 150, 168}),
#   frozenset({37, 49, 144, 257}),
#   frozenset({89, 200, 205, 271}),
#   frozenset({99, 145, 156, 255}),
#   frozenset({74, 141, 198, 223})]]

# %%
# create a deep copy of the original set
import copy
ids_clustered_new = copy.deepcopy(ids_clustered)
ids_clustered_new
# Out:
# [[frozenset({0, 7, 34, 51, 76, 100, 106, 178, 236}),
#   frozenset({6, 53, 55, 93, 138, 185, 190, 228, 297}),
#   frozenset({22, 80, 133, 170, 204, 222, 241, 253}),
#   frozenset({91, 137, 151, 214, 216, 220, 232}),
#   frozenset({14, 111, 115, 175, 184, 247, 254}),
#   frozenset({15, 84, 107, 143, 160, 233, 235}),
#   frozenset({10, 70, 87, 188, 199, 281, 296}),
#   frozenset({96, 201, 234, 269, 278, 284}),
#   frozenset({4, 68, 69, 72}),
#   frozenset({82, 101, 122, 262}),
#   frozenset({3, 43, 78, 266}),
#   frozenset({64, 225, 259}),
#   frozenset({33, 227})],
#  [frozenset({30, 42, 45, 120, 136, 149, 208, 260, 285}),
#   frozenset({21, 46, 54, 83, 109, 126, 226, 288}),
#   frozenset({11, 24, 155, 238, 251, 263, 276, 287}),
#   frozenset({17, 135, 153, 171, 180, 209, 275, 294}),
#   frozenset({18, 28, 50, 98, 104, 108, 207, 256}),
#   frozenset({12, 16, 134, 152, 154, 193, 237}),
#   frozenset({44, 62, 97, 159, 167, 187, 242}),
#   frozenset({20, 92, 158, 252, 293}),
#   frozenset({172, 194, 217, 286}),
#   frozenset({66, 103, 183, 280}),
#   frozenset({124, 195, 212, 279}),
#   frozenset({58, 140, 267, 299}),
#   frozenset({5, 35, 105})],
#  [frozenset({13, 56, 86, 95, 128, 129, 177, 182}),
#   frozenset({81, 125, 157, 224, 245, 258, 273}),
#   frozenset({52, 165, 179, 203, 210, 213, 246}),
#   frozenset({9, 31, 40, 60, 67, 75}),
#   frozenset({61, 110, 130, 148, 196, 219}),
#   frozenset({36, 102, 139, 142, 215, 248}),
#   frozenset({88, 161, 176, 250, 283}),
#   frozenset({32, 189, 274, 295, 298}),
#   frozenset({23, 65, 166, 192}),
#   frozenset({1, 132, 186}),
#   frozenset({47, 202, 249}),
#   frozenset({77, 79}),
#   frozenset({231, 244})],
#  [frozenset({2, 57, 63, 90, 118, 169, 211, 264, 268, 290}),
#   frozenset({19, 25, 27, 39, 71, 117, 173, 174, 282}),
#   frozenset({85, 112, 147, 191, 218, 261, 265, 270}),
#   frozenset({121, 123, 164, 230, 240, 243}),
#   frozenset({48, 59, 131, 221}),
#   frozenset({113, 239, 291}),
#   frozenset({116, 181})],
#  [frozenset({26, 41, 163, 272, 289, 292}),
#   frozenset({73, 94, 127, 146, 197, 277}),
#   frozenset({8, 29, 38, 150, 168}),
#   frozenset({37, 49, 144, 257}),
#   frozenset({89, 200, 205, 271}),
#   frozenset({99, 145, 156, 255}),
#   frozenset({74, 141, 198, 223})]]

# %%
""" 
Below is the code you can only run once on Jupyter but which seems to work fine in PyCharm. It takes the
two-dimensional list of IDs per cluster from the previous cell and the number of final classes. 
For each class, it takes groups of students from the list of IDs per cluster until max size of class 
is reached. It returns a two-dimensional list of IDs per final class and what is left of the original 
list of clusters, so we can check if there are students who were not assigned to any class and add them later. 
""" 

length = len(new_df_friends) # length of first dataframe = overall number of students

def form_classes(lst_ids_clustered, number_classes):
    ids_classes = []
    max_size = length // number_classes + 5
    for number in range(number_classes):
        ids_classes.append([]) # append an empty list for every class to overall list
    for every_class in ids_classes:
        size = 0
        while size < max_size:
            for lst in lst_ids_clustered: # go through the clusters within list of IDs/groups of students
                if len(lst[0]) <= max_size - size: # take group of students from cluster if not too big
                    every_class.append(lst[0]) # add group to class
                    size += len(lst[0]) # change remaining class size
                    del lst[0] # delete group of students from cluster
                    if lst == []:
                        lst_ids_clustered.remove(lst) # delete cluster if empty
                else:
                    size = max_size
    return ids_classes, lst_ids_clustered

a, b = form_classes(ids_clustered_new, 9)
print(a)
print(b)
# Out:
# [[frozenset({0, 34, 100, 7, 106, 76, 236, 178, 51}), frozenset({260, 136, 42, 45, 208, 149, 120, 285, 30}), frozenset({128, 129, 13, 177, 86, 182, 56, 95})], [frozenset({228, 6, 297, 138, 53, 55, 185, 93, 190}), frozenset({288, 226, 109, 46, 83, 21, 54, 126}), frozenset({224, 258, 81, 273, 245, 157, 125})], [frozenset({133, 170, 204, 80, 241, 22, 253, 222}), frozenset({263, 11, 155, 238, 276, 24, 251, 287}), frozenset({165, 203, 210, 179, 52, 213, 246})], [frozenset({232, 137, 214, 151, 216, 91, 220}), frozenset({294, 135, 171, 209, 17, 275, 180, 153}), frozenset({67, 40, 9, 75, 60, 31}), frozenset({2, 290, 264, 169, 268, 211, 118, 57, 90, 63})], [frozenset({14, 111, 175, 115, 247, 184, 254}), frozenset({256, 98, 104, 108, 207, 50, 18, 28}), frozenset({130, 196, 110, 148, 219, 61}), frozenset({71, 39, 173, 174, 19, 117, 25, 282, 27})], [frozenset({160, 233, 107, 235, 15, 143, 84}), frozenset({193, 134, 12, 237, 16, 152, 154}), frozenset({36, 102, 139, 142, 215, 248}), frozenset({261, 265, 270, 112, 147, 85, 218, 191})], [frozenset({70, 199, 296, 10, 87, 281, 188}), frozenset({97, 167, 44, 242, 187, 62, 159}), frozenset({161, 176, 88, 250, 283}), frozenset({164, 230, 240, 243, 121, 123}), frozenset({289, 163, 292, 41, 272, 26})], [frozenset({96, 201, 234, 269, 278, 284}), frozenset({293, 92, 20, 252, 158}), frozenset({32, 295, 298, 274, 189}), frozenset({48, 59, 131, 221}), frozenset({197, 73, 146, 277, 94, 127}), frozenset({72, 4, 69, 68})], [frozenset({82, 101, 122, 262}), frozenset({217, 194, 172, 286}), frozenset({192, 65, 166, 23}), frozenset({113, 291, 239}), frozenset({38, 8, 168, 150, 29}), frozenset({43, 266, 3, 78}), frozenset({280, 183, 66, 103}), frozenset({1, 186, 132})]]
# [[frozenset({64, 225, 259}), frozenset({33, 227})], [frozenset({212, 195, 124, 279}), frozenset({299, 58, 267, 140}), frozenset({105, 35, 5})], [frozenset({249, 202, 47}), frozenset({77, 79}), frozenset({244, 231})], [frozenset({116, 181})], [frozenset({144, 49, 37, 257}), frozenset({200, 89, 205, 271}), frozenset({145, 99, 156, 255}), frozenset({74, 141, 198, 223})]]

# %%
# new set has less elements after running through the function
ids_clustered_new
# Out:
# [[frozenset({64, 225, 259}), frozenset({33, 227})],
#  [frozenset({124, 195, 212, 279}),
#   frozenset({58, 140, 267, 299}),
#   frozenset({5, 35, 105})],
#  [frozenset({47, 202, 249}), frozenset({77, 79}), frozenset({231, 244})],
#  [frozenset({116, 181})],
#  [frozenset({37, 49, 144, 257}),
#   frozenset({89, 200, 205, 271}),
#   frozenset({99, 145, 156, 255}),
#   frozenset({74, 141, 198, 223})]]

# %%
# original set still intact
ids_clustered
# Out:
# [[frozenset({0, 7, 34, 51, 76, 100, 106, 178, 236}),
#   frozenset({6, 53, 55, 93, 138, 185, 190, 228, 297}),
#   frozenset({22, 80, 133, 170, 204, 222, 241, 253}),
#   frozenset({91, 137, 151, 214, 216, 220, 232}),
#   frozenset({14, 111, 115, 175, 184, 247, 254}),
#   frozenset({15, 84, 107, 143, 160, 233, 235}),
#   frozenset({10, 70, 87, 188, 199, 281, 296}),
#   frozenset({96, 201, 234, 269, 278, 284}),
#   frozenset({4, 68, 69, 72}),
#   frozenset({82, 101, 122, 262}),
#   frozenset({3, 43, 78, 266}),
#   frozenset({64, 225, 259}),
#   frozenset({33, 227})],
#  [frozenset({30, 42, 45, 120, 136, 149, 208, 260, 285}),
#   frozenset({21, 46, 54, 83, 109, 126, 226, 288}),
#   frozenset({11, 24, 155, 238, 251, 263, 276, 287}),
#   frozenset({17, 135, 153, 171, 180, 209, 275, 294}),
#   frozenset({18, 28, 50, 98, 104, 108, 207, 256}),
#   frozenset({12, 16, 134, 152, 154, 193, 237}),
#   frozenset({44, 62, 97, 159, 167, 187, 242}),
#   frozenset({20, 92, 158, 252, 293}),
#   frozenset({172, 194, 217, 286}),
#   frozenset({66, 103, 183, 280}),
#   frozenset({124, 195, 212, 279}),
#   frozenset({58, 140, 267, 299}),
#   frozenset({5, 35, 105})],
#  [frozenset({13, 56, 86, 95, 128, 129, 177, 182}),
#   frozenset({81, 125, 157, 224, 245, 258, 273}),
#   frozenset({52, 165, 179, 203, 210, 213, 246}),
#   frozenset({9, 31, 40, 60, 67, 75}),
#   frozenset({61, 110, 130, 148, 196, 219}),
#   frozenset({36, 102, 139, 142, 215, 248}),
#   frozenset({88, 161, 176, 250, 283}),
#   frozenset({32, 189, 274, 295, 298}),
#   frozenset({23, 65, 166, 192}),
#   frozenset({1, 132, 186}),
#   frozenset({47, 202, 249}),
#   frozenset({77, 79}),
#   frozenset({231, 244})],
#  [frozenset({2, 57, 63, 90, 118, 169, 211, 264, 268, 290}),
#   frozenset({19, 25, 27, 39, 71, 117, 173, 174, 282}),
#   frozenset({85, 112, 147, 191, 218, 261, 265, 270}),
#   frozenset({121, 123, 164, 230, 240, 243}),
#   frozenset({48, 59, 131, 221}),
#   frozenset({113, 239, 291}),
#   frozenset({116, 181})],
#  [frozenset({26, 41, 163, 272, 289, 292}),
#   frozenset({73, 94, 127, 146, 197, 277}),
#   frozenset({8, 29, 38, 150, 168}),
#   frozenset({37, 49, 144, 257}),
#   frozenset({89, 200, 205, 271}),
#   frozenset({99, 145, 156, 255}),
#   frozenset({74, 141, 198, 223})]]

# %%
# convert frozenset1 to 2d list

def convert_set_to_list1(st):
    new_lst = []
    for i in st:
        temp_lst = []
        for e in i:
            for j in e:
                temp_lst.append(j)
        new_lst.append(temp_lst)
    return new_lst

c = convert_set_to_list1(a)
c
# Out:
# [[0,
#   34,
#   100,
#   7,
#   106,
#   76,
#   236,
#   178,
#   51,
#   260,
#   136,
#   42,
#   45,
#   208,
#   149,
#   120,
#   285,
#   30,
#   128,
#   129,
#   13,
#   177,
#   86,
#   182,
#   56,
#   95],
#  [228,
#   6,
#   297,
#   138,
#   53,
#   55,
#   185,
#   93,
#   190,
#   288,
#   226,
#   109,
#   46,
#   83,
#   21,
#   54,
#   126,
#   224,
#   258,
#   81,
#   273,
#   245,
#   157,
#   125],
#  [133,
#   170,
#   204,
#   80,
#   241,
#   22,
#   253,
#   222,
#   263,
#   11,
#   155,
#   238,
#   276,
#   24,
#   251,
#   287,
#   165,
#   203,
#   210,
#   179,
#   52,
#   213,
#   246],
#  [232,
#   137,
#   214,
#   151,
#   216,
#   91,
#   220,
#   294,
#   135,
#   171,
#   209,
#   17,
#   275,
#   180,
#   153,
#   67,
#   40,
#   9,
#   75,
#   60,
#   31,
#   2,
#   290,
#   264,
#   169,
#   268,
#   211,
#   118,
#   57,
#   90,
#   63],
#  [14,
#   111,
#   175,
#   115,
#   247,
#   184,
#   254,
#   256,
#   98,
#   104,
#   108,
#   207,
#   50,
#   18,
#   28,
#   130,
#   196,
#   110,
#   148,
#   219,
#   61,
#   71,
#   39,
#   173,
#   174,
#   19,
#   117,
#   25,
#   282,
#   27],
#  [160,
#   233,
#   107,
#   235,
#   15,
#   143,
#   84,
#   193,
#   134,
#   12,
#   237,
#   16,
#   152,
#   154,
#   36,
#   102,
#   139,
#   142,
#   215,
#   248,
#   261,
#   265,
#   270,
#   112,
#   147,
#   85,
#   218,
#   191],
#  [70,
#   199,
#   296,
#   10,
#   87,
#   281,
#   188,
#   97,
#   167,
#   44,
#   242,
#   187,
#   62,
#   159,
#   161,
#   176,
#   88,
#   250,
#   283,
#   164,
#   230,
#   240,
#   243,
#   121,
#   123,
#   289,
#   163,
#   292,
#   41,
#   272,
#   26],
#  [96,
#   201,
#   234,
#   269,
#   278,
#   284,
#   293,
#   92,
#   20,
#   252,
#   158,
#   32,
#   295,
#   298,
#   274,
#   189,
#   48,
#   59,
#   131,
#   221,
#   197,
#   73,
#   146,
#   277,
#   94,
#   127,
#   72,
#   4,
#   69,
#   68],
#  [82,
#   101,
#   122,
#   262,
#   217,
#   194,
#   172,
#   286,
#   192,
#   65,
#   166,
#   23,
#   113,
#   291,
#   239,
#   38,
#   8,
#   168,
#   150,
#   29,
#   43,
#   266,
#   3,
#   78,
#   280,
#   183,
#   66,
#   103,
#   1,
#   186,
#   132]]

# %%
# convert frozenset2 to 2d list

def convert_set_to_list2(st):
    new_lst = []
    for i in st:
        for e in i:
            temp_lst = []
            for j in e:
                temp_lst.append(j)
            new_lst.append(temp_lst)
    return new_lst

d = convert_set_to_list2(b)
sorted(d, key=len)

#smallest = d.index(min(total_list, key=len))
# Out:
# [[33, 227],
#  [77, 79],
#  [244, 231],
#  [116, 181],
#  [64, 225, 259],
#  [105, 35, 5],
#  [249, 202, 47],
#  [212, 195, 124, 279],
#  [299, 58, 267, 140],
#  [144, 49, 37, 257],
#  [200, 89, 205, 271],
#  [145, 99, 156, 255],
#  [74, 141, 198, 223]]

# %%
min_val = min([len(test_dict[ele]) for ele in test_dict])
res = []
for ele in test_dict:
    if len(test_dict[ele]) == min_val:
        res.append(ele)

# %%
# adding remaining students
    
def add_rest1(lst_classes, lst_rest):
    merged_list = []
    list1 = sorted(lst_classes, key=len)
    list2 = sorted(lst_rest, key=len, reverse=True)
    for i in range(max((len(list1), len(list2)))):
          while True:
            try:
                list3 = [list1[i], list2[i]]
            except IndexError:
                if len(list1) > len(list2):
                    list2.append([])
                    list3 = [list1[i], list2[i]]
                elif len(list1) < len(list2):
                    list1.append([])
                    list3 = [list1[i], list2[i]]
                continue  
            merged_list.append(list3)
            break
    merged_list_cleaned = []
    for i in merged_list:
        list4 = [] 
        for e in i:            
            for j in e:
                list4.append(j)
        merged_list_cleaned.append(list4)            
    return merged_list_cleaned


final_classes1 = add_rest1(c,d)
final_classes1
# Out:
# [[133,
#   170,
#   204,
#   80,
#   241,
#   22,
#   253,
#   222,
#   263,
#   11,
#   155,
#   238,
#   276,
#   24,
#   251,
#   287,
#   165,
#   203,
#   210,
#   179,
#   52,
#   213,
#   246,
#   212,
#   195,
#   124,
#   279],
#  [228,
#   6,
#   297,
#   138,
#   53,
#   55,
#   185,
#   93,
#   190,
#   288,
#   226,
#   109,
#   46,
#   83,
#   21,
#   54,
#   126,
#   224,
#   258,
#   81,
#   273,
#   245,
#   157,
#   125,
#   299,
#   58,
#   267,
#   140],
#  [0,
#   34,
#   100,
#   7,
#   106,
#   76,
#   236,
#   178,
#   51,
#   260,
#   136,
#   42,
#   45,
#   208,
#   149,
#   120,
#   285,
#   30,
#   128,
#   129,
#   13,
#   177,
#   86,
#   182,
#   56,
#   95,
#   144,
#   49,
#   37,
#   257],
#  [160,
#   233,
#   107,
#   235,
#   15,
#   143,
#   84,
#   193,
#   134,
#   12,
#   237,
#   16,
#   152,
#   154,
#   36,
#   102,
#   139,
#   142,
#   215,
#   248,
#   261,
#   265,
#   270,
#   112,
#   147,
#   85,
#   218,
#   191,
#   200,
#   89,
#   205,
#   271],
#  [14,
#   111,
#   175,
#   115,
#   247,
#   184,
#   254,
#   256,
#   98,
#   104,
#   108,
#   207,
#   50,
#   18,
#   28,
#   130,
#   196,
#   110,
#   148,
#   219,
#   61,
#   71,
#   39,
#   173,
#   174,
#   19,
#   117,
#   25,
#   282,
#   27,
#   145,
#   99,
#   156,
#   255],
#  [96,
#   201,
#   234,
#   269,
#   278,
#   284,
#   293,
#   92,
#   20,
#   252,
#   158,
#   32,
#   295,
#   298,
#   274,
#   189,
#   48,
#   59,
#   131,
#   221,
#   197,
#   73,
#   146,
#   277,
#   94,
#   127,
#   72,
#   4,
#   69,
#   68,
#   74,
#   141,
#   198,
#   223],
#  [232,
#   137,
#   214,
#   151,
#   216,
#   91,
#   220,
#   294,
#   135,
#   171,
#   209,
#   17,
#   275,
#   180,
#   153,
#   67,
#   40,
#   9,
#   75,
#   60,
#   31,
#   2,
#   290,
#   264,
#   169,
#   268,
#   211,
#   118,
#   57,
#   90,
#   63,
#   64,
#   225,
#   259],
#  [70,
#   199,
#   296,
#   10,
#   87,
#   281,
#   188,
#   97,
#   167,
#   44,
#   242,
#   187,
#   62,
#   159,
#   161,
#   176,
#   88,
#   250,
#   283,
#   164,
#   230,
#   240,
#   243,
#   121,
#   123,
#   289,
#   163,
#   292,
#   41,
#   272,
#   26,
#   105,
#   35,
#   5],
#  [82,
#   101,
#   122,
#   262,
#   217,
#   194,
#   172,
#   286,
#   192,
#   65,
#   166,
#   23,
#   113,
#   291,
#   239,
#   38,
#   8,
#   168,
#   150,
#   29,
#   43,
#   266,
#   3,
#   78,
#   280,
#   183,
#   66,
#   103,
#   1,
#   186,
#   132,
#   249,
#   202,
#   47],
#  [33, 227],
#  [77, 79],
#  [244, 231],
#  [116, 181]]

# %%
final_classes1[9:]
# Out:
# [[33, 227], [77, 79], [244, 231], [116, 181]]

# %%
def add_rest2(cleaned_lst_classes1, number_classes):
    merged_list = []
    list1 = sorted(cleaned_lst_classes1[:number_classes], key = len)
    list2 = sorted(cleaned_lst_classes1[number_classes:], key = len, reverse = True)
    for i in range(max((len(list1), len(list2)))):
          while True:
            try:
                list3 = [list1[i], list2[i]]
            except IndexError:
                if len(list1) > len(list2):
                    list2.append([])
                    list3 = [list1[i], list2[i]]
                elif len(list1) < len(list2):
                    list1.append([])
                    list3 = [list1[i], list2[i]]
                continue  
            merged_list.append(list3)
            break
    merged_list_cleaned = []
    for i in merged_list:
        list4 = [] 
        for e in i:            
            for j in e:
                list4.append(j)
        merged_list_cleaned.append(list4)            
    return merged_list_cleaned

final_classes2 = add_rest2(final_classes1, 9)
final_classes2
# Out:
# [[133,
#   170,
#   204,
#   80,
#   241,
#   22,
#   253,
#   222,
#   263,
#   11,
#   155,
#   238,
#   276,
#   24,
#   251,
#   287,
#   165,
#   203,
#   210,
#   179,
#   52,
#   213,
#   246,
#   212,
#   195,
#   124,
#   279,
#   33,
#   227],
#  [228,
#   6,
#   297,
#   138,
#   53,
#   55,
#   185,
#   93,
#   190,
#   288,
#   226,
#   109,
#   46,
#   83,
#   21,
#   54,
#   126,
#   224,
#   258,
#   81,
#   273,
#   245,
#   157,
#   125,
#   299,
#   58,
#   267,
#   140,
#   77,
#   79],
#  [0,
#   34,
#   100,
#   7,
#   106,
#   76,
#   236,
#   178,
#   51,
#   260,
#   136,
#   42,
#   45,
#   208,
#   149,
#   120,
#   285,
#   30,
#   128,
#   129,
#   13,
#   177,
#   86,
#   182,
#   56,
#   95,
#   144,
#   49,
#   37,
#   257,
#   244,
#   231],
#  [160,
#   233,
#   107,
#   235,
#   15,
#   143,
#   84,
#   193,
#   134,
#   12,
#   237,
#   16,
#   152,
#   154,
#   36,
#   102,
#   139,
#   142,
#   215,
#   248,
#   261,
#   265,
#   270,
#   112,
#   147,
#   85,
#   218,
#   191,
#   200,
#   89,
#   205,
#   271,
#   116,
#   181],
#  [14,
#   111,
#   175,
#   115,
#   247,
#   184,
#   254,
#   256,
#   98,
#   104,
#   108,
#   207,
#   50,
#   18,
#   28,
#   130,
#   196,
#   110,
#   148,
#   219,
#   61,
#   71,
#   39,
#   173,
#   174,
#   19,
#   117,
#   25,
#   282,
#   27,
#   145,
#   99,
#   156,
#   255],
#  [96,
#   201,
#   234,
#   269,
#   278,
#   284,
#   293,
#   92,
#   20,
#   252,
#   158,
#   32,
#   295,
#   298,
#   274,
#   189,
#   48,
#   59,
#   131,
#   221,
#   197,
#   73,
#   146,
#   277,
#   94,
#   127,
#   72,
#   4,
#   69,
#   68,
#   74,
#   141,
#   198,
#   223],
#  [232,
#   137,
#   214,
#   151,
#   216,
#   91,
#   220,
#   294,
#   135,
#   171,
#   209,
#   17,
#   275,
#   180,
#   153,
#   67,
#   40,
#   9,
#   75,
#   60,
#   31,
#   2,
#   290,
#   264,
#   169,
#   268,
#   211,
#   118,
#   57,
#   90,
#   63,
#   64,
#   225,
#   259],
#  [70,
#   199,
#   296,
#   10,
#   87,
#   281,
#   188,
#   97,
#   167,
#   44,
#   242,
#   187,
#   62,
#   159,
#   161,
#   176,
#   88,
#   250,
#   283,
#   164,
#   230,
#   240,
#   243,
#   121,
#   123,
#   289,
#   163,
#   292,
#   41,
#   272,
#   26,
#   105,
#   35,
#   5],
#  [82,
#   101,
#   122,
#   262,
#   217,
#   194,
#   172,
#   286,
#   192,
#   65,
#   166,
#   23,
#   113,
#   291,
#   239,
#   38,
#   8,
#   168,
#   150,
#   29,
#   43,
#   266,
#   3,
#   78,
#   280,
#   183,
#   66,
#   103,
#   1,
#   186,
#   132,
#   249,
#   202,
#   47]]

# %%
# check number of students in final classes

for e in final_classes2:
    x = 0
    for i in e:
        x += 1
    print(x)
# Out:
# 29
# 30
# 32
# 34
# 34
# 34
# 34
# 34
# 34

# %%
def make_final_dfs(first_df, list_final_classes):
    list_dfs = []
    for e in list_final_classes:
        new_df = first_df[first_df["id"].isin(e)]
        list_dfs.append(new_df)
    return list_dfs

d = make_final_dfs(new_df_friends, final_classes2)
d[0]
# Out:
#       id  previous_class_int  color_int  gender_int  reading_int  hobby_int  \
# 83    22                   5          3           0            1          0
# 84    80                   5          4           0            2          1
# 85   133                   5          4           0            3          4
# 86   170                   5          0           0            0          4
# 87   204                   5          5           0            1          0
# 88   222                   5          5           0            2          3
# 90   241                   5          5           0            2          3
# 97    52                   5          4           1            2          0
# 101  179                   5          5           1            0          3
# 102  203                   5          3           1            0          4
# 103  210                   5          0           1            2          0
# 104  213                   5          5           1            0          1
# 105  246                   5          0           1            1          0
# 110   33                   6          3           0            0          2
# 120  227                   6          4           0            2          2
# 157   11                   8          4           1            2          0
# 159   24                   8          5           1            1          1
# 167  238                   8          3           1            1          3
# 168  251                   8          0           1            1          2
# 169  263                   8          1           1            3          3
# 170  276                   8          0           1            3          1
# 171  287                   8          0           1            3          0
# 274  195                  13          0           1            0          1
# 276  212                  13          3           1            2          1
# 278  279                  13          1           1            0          1
#
#      language_int  introverted_int  siblings  friend1  friend2
# 83              0                1         0      222      253
# 84              2                1         4      253      241
# 85              0                0         0       80      222
# 86              0                1         3      204      222
# 87              2                0         3      241      222
# 88              4                1         4      253      253
# 90              0                0         4      253      253
# 97              1                1         2      165      105
# 101             2                1         0      289      203
# 102             2                0         2      210       26
# 103             4                1         4      246       26
# 104             4                0         3       52      203
# 105             4                1         1       52      289
# 110             2                1         0      247      101
# 120             1                1         2       33      175
# 157             3                0         0      263      126
# 159             2                1         2      155      155
# 167             2                1         4      155      251
# 168             3                1         3      287      263
# 169             4                1         3      287      287
# 170             3                1         0      251      155
# 171             0                1         4      251      155
# 274             4                1         4      124      212
# 276             1                1         4      195      124
# 278             2                1         4      124      124

# %%
def get_csv_files(list_dfs):
    x = 0
    for i in list_dfs:
        x += 1
        out_filename = "class" + str(x) + ".csv"
        i.to_csv(out_filename, index = True)

get_csv_files(d)

# %% [markdown]
# ### some tests done by Jonas

# %%
# copy class df with class information

lst_final_df = []
x = 0

for df in d:
    x += 1
    class_df = df.copy()
    class_df["class"] = x
    lst_final_df.append(class_df)

final_df = pd.concat(lst_final_df)
final_df.reset_index(drop=True, inplace=True)
final_df
# Out:
#       id  previous_class_int  color_int  gender_int  reading_int  hobby_int  \
# 0     22                   5          3           0            1          0
# 1     80                   5          4           0            2          1
# 2    133                   5          4           0            3          4
# 3    170                   5          0           0            0          4
# 4    204                   5          5           0            1          0
# ..   ...                 ...        ...         ...          ...        ...
# 245  239                  11          3           1            3          2
# 246  291                  11          5           1            0          3
# 247   43                  13          2           0            2          2
# 248   78                  13          1           0            3          4
# 249  266                  13          0           0            0          2
#
#      language_int  introverted_int  siblings  friend1  friend2  class
# 0               0                1         0      222      253      1
# 1               2                1         4      253      241      1
# 2               0                0         0       80      222      1
# 3               0                1         3      204      222      1
# 4               2                0         3      241      222      1
# ..            ...              ...       ...      ...      ...    ...
# 245             1                0         2      113       16      9
# 246             4                0         1      154        8      9
# 247             1                1         1       25       19      9
# 248             3                1         1        3       43      9
# 249             2                0         0        3       43      9
#
# [250 rows x 12 columns]

# %%
# loop append cluster dfs to large df for all students
original_df = list_sorted[0].append([list_sorted[1], list_sorted[2], list_sorted[3]])
original_df.reset_index(drop=True, inplace=True)
original_df
# Out:
#                                                id  number_students  \
# 0          (0, 34, 100, 7, 106, 76, 236, 178, 51)                9
# 1        (228, 6, 297, 138, 53, 55, 185, 93, 190)                9
# 2          (133, 170, 204, 80, 241, 22, 253, 222)                8
# 3              (214, 151, 232, 137, 91, 220, 216)                7
# 4              (115, 254, 247, 184, 111, 14, 175)                7
# 5               (160, 84, 233, 107, 15, 235, 143)                7
# 6                (199, 70, 87, 296, 281, 10, 188)                7
# 7                   (96, 278, 201, 234, 284, 269)                6
# 8                                 (72, 4, 68, 69)                4
# 9                             (82, 101, 122, 262)                4
# 10                               (3, 266, 43, 78)                4
# 11                                 (64, 225, 259)                3
# 12                                      (33, 227)                2
# 13     (260, 136, 42, 45, 208, 149, 120, 285, 30)                9
# 14           (288, 226, 109, 46, 83, 21, 54, 126)                8
# 15         (263, 11, 238, 251, 276, 24, 155, 287)                8
# 16        (294, 135, 171, 209, 17, 275, 180, 153)                8
# 17           (256, 98, 104, 108, 207, 50, 18, 28)                8
# 18              (16, 193, 134, 152, 154, 12, 237)                7
# 19               (97, 242, 167, 187, 44, 62, 159)                7
# 20                        (20, 293, 252, 158, 92)                5
# 21                           (217, 194, 172, 286)                4
# 22                            (280, 66, 103, 183)                4
# 23                           (124, 195, 212, 279)                4
# 24                            (267, 58, 299, 140)                4
# 25                                   (105, 35, 5)                3
# 26           (128, 129, 13, 177, 86, 182, 56, 95)                8
# 27             (224, 81, 258, 273, 245, 125, 157)                7
# 28             (210, 179, 52, 213, 165, 246, 203)                7
# 29                        (67, 40, 9, 75, 60, 31)                6
# 30                  (130, 148, 196, 219, 61, 110)                6
# 31                  (36, 102, 215, 248, 139, 142)                6
# 32                       (176, 161, 88, 250, 283)                5
# 33                       (32, 274, 295, 298, 189)                5
# 34                             (192, 65, 166, 23)                4
# 35                                  (1, 186, 132)                3
# 36                                 (249, 202, 47)                3
# 37                                       (77, 79)                2
# 38                                     (244, 231)                2
# 39  (2, 290, 264, 169, 268, 211, 118, 57, 90, 63)               10
# 40       (39, 71, 173, 174, 19, 117, 25, 282, 27)                9
# 41        (261, 265, 270, 112, 147, 85, 218, 191)                8
# 42                 (240, 243, 164, 230, 121, 123)                6
# 43                             (48, 59, 131, 221)                4
# 44                                (113, 291, 239)                3
# 45                                     (116, 181)                2
#
#     gender_int  color_int  reading_int  hobby_int  language_int  \
# 0          0.0        1.6          2.0        1.9           1.4
# 1          0.0        3.0          0.8        2.1           2.1
# 2          0.0        3.7          1.6        2.1           1.1
# 3          0.0        3.8          1.7        2.7           2.2
# 4          0.0        2.6          1.3        1.4           1.4
# 5          0.0        3.7          2.7        1.7           2.2
# 6          0.0        1.7          2.7        1.7           1.7
# 7          0.0        2.6          0.6        2.2           2.0
# 8          0.0        3.0          2.5        0.5           2.0
# 9          0.0        2.7          2.3        1.3           2.0
# 10         0.0        1.0          1.7        2.7           2.0
# 11         0.0        3.3          2.0        1.3           2.7
# 12         0.0        3.5          1.0        2.0           1.5
# 13         1.0        2.0          2.0        2.1           1.8
# 14         1.0        2.5          1.5        1.5           2.0
# 15         1.0        1.9          2.0        1.4           2.4
# 16         1.0        2.2          1.2        1.7           2.5
# 17         1.0        2.7          1.9        2.3           1.7
# 18         1.0        2.3          1.2        1.2           1.8
# 19         1.0        2.7          1.0        1.7           1.5
# 20         1.0        1.0          2.2        1.0           1.0
# 21         1.0        3.0          2.7        1.3           0.7
# 22         1.0        3.0          2.2        2.5           1.2
# 23         1.0        1.3          0.7        1.0           2.3
# 24         1.0        3.2          1.0        1.5           1.8
# 25         1.0        0.7          2.7        2.3           2.3
# 26         1.0        2.0          1.6        1.8           2.6
# 27         1.0        3.0          0.8        1.8           1.5
# 28         1.0        2.8          0.8        1.3           2.8
# 29         1.0        1.4          1.2        1.6           1.4
# 30         1.0        2.2          0.8        1.0           2.4
# 31         0.0        1.0          0.8        1.8           1.5
# 32         1.0        2.2          1.8        3.0           2.0
# 33         1.0        2.8          1.2        2.0           2.0
# 34         1.0        1.7          1.0        1.3           1.7
# 35         1.0        2.3          1.3        1.0           2.7
# 36         0.0        1.0          1.3        0.3           3.0
# 37         1.0        3.5          0.5        1.5           1.5
# 38         0.0        1.0          2.0        1.0           3.0
# 39         0.0        2.7          1.7        2.4           2.6
# 40         0.0        2.5          1.0        2.0           1.9
# 41         0.0        3.5          1.2        2.0           3.3
# 42         0.0        2.4          1.2        1.2           2.8
# 43         0.0        2.2          1.8        2.8           3.5
# 44         1.0        2.7          1.7        2.7           2.7
# 45         0.0        2.0          0.0        2.0           3.0
#
#     introverted_int  siblings  previous_class_int  clusters
# 0               0.6       1.0                 0.0         3
# 1               0.6       1.9                 8.0         3
# 2               0.6       2.6                 5.0         3
# 3               0.5       1.2                 3.0         3
# 4               0.4       1.9                 6.0         3
# 5               0.5       1.8                 7.0         3
# 6               0.8       1.8                10.0         3
# 7               0.8       0.8                12.0         3
# 8               0.5       1.0                 4.0         3
# 9               0.7       1.0                 6.0         3
# 10              0.7       0.7                13.0         3
# 11              0.7       2.0                 7.0         3
# 12              1.0       1.0                 6.0         3
# 13              0.8       2.0                12.0         4
# 14              0.5       1.2                 8.0         4
# 15              0.9       2.3                 8.0         4
# 16              0.7       0.8                 9.0         4
# 17              0.4       2.0                10.0         4
# 18              0.5       2.2                11.0         4
# 19              0.7       2.2                14.0         4
# 20              0.8       1.2                 2.0         4
# 21              0.3       2.0                 4.0         4
# 22              0.8       3.2                10.0         4
# 23              1.0       4.0                13.0         4
# 24              0.8       2.5                14.0         4
# 25              0.7       2.3                 5.0         4
# 26              0.1       2.6                 7.0         1
# 27              0.3       1.5                 4.0         1
# 28              0.7       2.0                 5.0         1
# 29              0.4       2.2                 0.0         1
# 30              0.2       0.4                 1.0         1
# 31              0.2       3.5                 2.0         1
# 32              0.2       2.6                 3.0         1
# 33              0.2       1.5                 3.0         1
# 34              0.3       1.0                 0.0         1
# 35              0.3       1.7                 0.0         1
# 36              0.0       2.3                 3.0         1
# 37              0.5       3.0                 0.0         1
# 38              0.0       1.0                 5.0         1
# 39              0.4       2.2                14.0         2
# 40              0.4       1.9                13.0         2
# 41              0.3       2.0                11.0         2
# 42              0.6       2.0                 9.0         2
# 43              0.5       1.8                12.0         2
# 44              0.3       1.3                11.0         2
# 45              0.0       4.0                 6.0         2

# %%
# expand list so every student is a row with cluster
expanded_original_df = original_df.explode("id")
expanded_original_df
# Out:
#      id  number_students  gender_int  color_int  reading_int  hobby_int  \
# 0     0                9         0.0        1.6          2.0        1.9
# 0    34                9         0.0        1.6          2.0        1.9
# 0   100                9         0.0        1.6          2.0        1.9
# 0     7                9         0.0        1.6          2.0        1.9
# 0   106                9         0.0        1.6          2.0        1.9
# ..  ...              ...         ...        ...          ...        ...
# 44  113                3         1.0        2.7          1.7        2.7
# 44  291                3         1.0        2.7          1.7        2.7
# 44  239                3         1.0        2.7          1.7        2.7
# 45  116                2         0.0        2.0          0.0        2.0
# 45  181                2         0.0        2.0          0.0        2.0
#
#     language_int  introverted_int  siblings  previous_class_int  clusters
# 0            1.4              0.6       1.0                 0.0         3
# 0            1.4              0.6       1.0                 0.0         3
# 0            1.4              0.6       1.0                 0.0         3
# 0            1.4              0.6       1.0                 0.0         3
# 0            1.4              0.6       1.0                 0.0         3
# ..           ...              ...       ...                 ...       ...
# 44           2.7              0.3       1.3                11.0         2
# 44           2.7              0.3       1.3                11.0         2
# 44           2.7              0.3       1.3                11.0         2
# 45           3.0              0.0       4.0                 6.0         2
# 45           3.0              0.0       4.0                 6.0         2
#
# [262 rows x 11 columns]

# %%
# merge expanded_original_df with final dfs
final_merged_df = final_df.merge(expanded_original_df[["id", "clusters"]], how="left", on="id")
final_merged_df
# Out:
#       id  previous_class_int  color_int  gender_int  reading_int  hobby_int  \
# 0     22                   5          3           0            1          0
# 1     80                   5          4           0            2          1
# 2    133                   5          4           0            3          4
# 3    170                   5          0           0            0          4
# 4    204                   5          5           0            1          0
# ..   ...                 ...        ...         ...          ...        ...
# 245  239                  11          3           1            3          2
# 246  291                  11          5           1            0          3
# 247   43                  13          2           0            2          2
# 248   78                  13          1           0            3          4
# 249  266                  13          0           0            0          2
#
#      language_int  introverted_int  siblings  friend1  friend2  class  \
# 0               0                1         0      222      253      1
# 1               2                1         4      253      241      1
# 2               0                0         0       80      222      1
# 3               0                1         3      204      222      1
# 4               2                0         3      241      222      1
# ..            ...              ...       ...      ...      ...    ...
# 245             1                0         2      113       16      9
# 246             4                0         1      154        8      9
# 247             1                1         1       25       19      9
# 248             3                1         1        3       43      9
# 249             2                0         0        3       43      9
#
#      clusters
# 0         3.0
# 1         3.0
# 2         3.0
# 3         3.0
# 4         3.0
# ..        ...
# 245       2.0
# 246       2.0
# 247       3.0
# 248       3.0
# 249       3.0
#
# [250 rows x 13 columns]

# %%
temp_df = final_merged_df[final_merged_df["class"]==1]
temp_df.head()
# Out:
#     id  previous_class_int  color_int  gender_int  reading_int  hobby_int  \
# 0   22                   5          3           0            1          0
# 1   80                   5          4           0            2          1
# 2  133                   5          4           0            3          4
# 3  170                   5          0           0            0          4
# 4  204                   5          5           0            1          0
#
#    language_int  introverted_int  siblings  friend1  friend2  class  clusters
# 0             0                1         0      222      253      1       3.0
# 1             2                1         4      253      241      1       3.0
# 2             0                0         0       80      222      1       3.0
# 3             0                1         3      204      222      1       3.0
# 4             2                0         3      241      222      1       3.0

# %%
# check if friend 1 is in class and calculate share of True
# TODO: maybe add a check for friend 2 when friend 1 wasn't found

# Wish score 10% lower than before - maybe different when we check for friend2?

def measure_wishs_granted(df):
    friend_found = df["friend1"].isin(df["id"]).value_counts(normalize=True).reset_index()
    friend_found.columns = ["friend_found", "share"]
    wish_score = round(friend_found.loc[friend_found["friend_found"]==True, "share"].values[0],2)
    
    return wish_score

# %%
# calculate median cluster share
# ideal: 1 / number of clusters (e.g., in case of four clusters the median should be 25%)
# Does this still apply when distribution of students is not 25% per cluster? So, when 50% of students are in cluster 0?

def measure_diversity(df, nb_clusters):
    
    # calculate ideal score
    ideal_score = 1/nb_clusters

    # calculate score for current class
    cluster_distribution = df["clusters"].value_counts(normalize=True).reset_index()
    cluster_distribution.columns = ["cluster", "share"]
    diversity_score = round(cluster_distribution["share"].median(),2) * nb_clusters # perfect split will turn to 1.0
    
    return diversity_score

# %%
# evaluate how well the final class is in terms of diversity and wishs granted

for current_class in pd.unique(final_merged_df["class"]):
    
    temp_df = final_merged_df[final_merged_df["class"]==current_class]
    
    diversity_score = measure_diversity(temp_df, 5)
    
    wish_score = measure_wishs_granted(temp_df)
    
    print(f"Class {current_class} has a diversity score of {diversity_score} and a wish score of {wish_score}.")
# Out:
# Class 1 has a diversity score of 1.7999999999999998 and a wish score of 0.6.
# Class 2 has a diversity score of 1.45 and a wish score of 0.86.
# Class 3 has a diversity score of 1.6500000000000001 and a wish score of 0.62.
# Class 4 has a diversity score of 1.3 and a wish score of 0.56.
# Class 5 has a diversity score of 1.3 and a wish score of 0.77.
# Class 6 has a diversity score of 1.05 and a wish score of 0.58.
# Class 7 has a diversity score of 1.3 and a wish score of 0.52.
# Class 8 has a diversity score of 1.1 and a wish score of 0.67.
# Class 9 has a diversity score of 1.3 and a wish score of 0.5.
# 0.5

# %%
# Class 3 has the worst diversity score. Why? Only two clusters
df = final_merged_df[final_merged_df["class"]==1]
cluster_distribution = df["clusters"].value_counts(normalize=True).reset_index()
cluster_distribution.columns = ["cluster", "share"]
cluster_distribution
# Out:
#    cluster  share
# 0      4.0   0.40
# 1      3.0   0.36
# 2      1.0   0.24

# %%
# Diversity distribution for class 2
df = final_merged_df[final_merged_df["class"]==6]
cluster_distribution = df["clusters"].value_counts(normalize=True).reset_index()
cluster_distribution.columns = ["cluster", "share"]
cluster_distribution
# Out:
#    cluster     share
# 0      3.0  0.368421
# 1      4.0  0.210526
# 2      2.0  0.210526
# 3      1.0  0.210526
