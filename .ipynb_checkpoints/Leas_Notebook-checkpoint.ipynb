# %% [markdown]
# # K-means clustering

# %% [markdown]
# ## Exploratory data analysis: mall customer segmentation data (kaggle)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

df1 = pd.read_csv("Mall_Customers.csv")
df1.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df1.rename(columns = {"Annual Income (k$)":"Income", "Spending Score (1-100)":"Spending Score"}, inplace = True)
df1.head()
# Out:
#    CustomerID  Gender  Age  Income  Spending Score
# 0           1    Male   19      15              39
# 1           2    Male   21      15              81
# 2           3  Female   20      16               6
# 3           4  Female   23      16              77
# 4           5  Female   31      17              40

# %%
df1.describe()
# Out:
#        CustomerID         Age      Income  Spending Score
# count  200.000000  200.000000  200.000000      200.000000
# mean   100.500000   38.850000   60.560000       50.200000
# std     57.879185   13.969007   26.264721       25.823522
# min      1.000000   18.000000   15.000000        1.000000
# 25%     50.750000   28.750000   41.500000       34.750000
# 50%    100.500000   36.000000   61.500000       50.000000
# 75%    150.250000   49.000000   78.000000       73.000000
# max    200.000000   70.000000  137.000000       99.000000

# %%
sns.pairplot(df1[["Age", "Income", "Spending Score"]])

# %% [markdown]
# ## Clustering mall customer segmentation data

# %%
import sklearn.cluster as cluster
kmeans = cluster.KMeans(n_clusters = 5, init = "k-means++", random_state = 42)
kmeans = kmeans.fit(df1[["Spending Score", "Income"]])
kmeans.cluster_centers_
# Out:
# array([[49.51851852, 55.2962963 ],
#        [17.11428571, 88.2       ],
#        [20.91304348, 26.30434783],
#        [79.36363636, 25.72727273],
#        [82.12820513, 86.53846154]])

# %%
df1["Clusters"] = kmeans.labels_
df1.head()
# Out:
#    CustomerID  Gender  Age  Income  Spending Score  Clusters
# 0           1    Male   19      15              39         2
# 1           2    Male   21      15              81         3
# 2           3  Female   20      16               6         2
# 3           4  Female   23      16              77         3
# 4           5  Female   31      17              40         2

# %%
df1["Clusters"].value_counts()
# Out:
# 0    81
# 4    39
# 1    35
# 2    23
# 3    22
# Name: Clusters, dtype: int64

# %%
sns.scatterplot(data = df1, x = "Income", y = "Spending Score", hue = "Clusters", palette = "Set2")
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Spending Score'>

# %% [markdown]
# ## Creating diverse customer groups

# %%
"""
First function creates list a of clustered dataframes (one df per cluster); second function takes list a,
splits clustered dataframes into required number of diverse groups (splits) and adds them to list b; third function 
combines splitted dataframes in list b into new (diverse) dataframes and adds them to list c.
"""
from functools import reduce

def create_clustered_dataframes(df):
    dataframes = []
    for i in df.Clusters.unique():
        temporary_df = df[df["Clusters"] == i]
        dataframes.append(temporary_df)
    return dataframes

clustered_dataframes = create_clustered_dataframes(df1)
clustered_dataframes[0]
# find out about sort_values (sort by clusters, take chunks of it)
# Out:
#     CustomerID  Gender  Age  Income  Spending Score  Clusters
# 0            1    Male   19      15              39         2
# 2            3  Female   20      16               6         2
# 4            5  Female   31      17              40         2
# 6            7  Female   35      18               6         2
# 8            9    Male   64      19               3         2
# 10          11    Male   67      19              14         2
# 12          13  Female   58      20              15         2
# 14          15    Male   37      20              13         2
# 16          17  Female   35      21              35         2
# 18          19    Male   52      23              29         2
# 20          21    Male   35      24              35         2
# 22          23  Female   46      25               5         2
# 24          25  Female   54      28              14         2
# 26          27  Female   45      28              32         2
# 28          29  Female   40      29              31         2
# 30          31    Male   60      30               4         2
# 32          33    Male   53      33               4         2
# 34          35  Female   49      33              14         2
# 36          37  Female   42      34              17         2
# 38          39  Female   36      37              26         2
# 40          41  Female   65      38              35         2
# 42          43    Male   48      39              36         2
# 44          45  Female   49      39              28         2

# %%
def split_dataframes(clustered_list, splits):
    dataframes_split = []
    for i in clustered_list: 
        index_to_split = round(len(i) / splits)
        start = 0
        end = index_to_split
        for split in range(splits):
            temporary_df = i.iloc[start:end, :]
            dataframes_split.append(temporary_df)
            start += index_to_split
            end += index_to_split
    return dataframes_split

split_clustered_dataframes = split_dataframes(clustered_dataframes, 4)
split_clustered_dataframes[0]
# Out:
#     CustomerID  Gender  Age  Income  Spending Score  Clusters
# 0            1    Male   19      15              39         2
# 2            3  Female   20      16               6         2
# 4            5  Female   31      17              40         2
# 6            7  Female   35      18               6         2
# 8            9    Male   64      19               3         2
# 10          11    Male   67      19              14         2

# %%
"""
Splits in split_dataframes_by_position has to be the same as splits in create_diverse_dataframes!
"""

def create_diverse_dataframes(split_list, splits):
    dataframes_diverse = []
    start = 0
    for split in range(splits):        
        if start <= splits - 1:
            new_dataframe_as_list = split_list[start::splits]
            new_dataframe = pd.concat(new_dataframe_as_list)
            dataframes_diverse.append(new_dataframe)
            start += 1
    return dataframes_diverse    
    
diverse_groups = create_diverse_dataframes(split_clustered_dataframes, 4)
diverse_groups[0].head(15)
# Out:
#     CustomerID  Gender  Age  Income  Spending Score  Clusters
# 0            1    Male   19      15              39         2
# 2            3  Female   20      16               6         2
# 4            5  Female   31      17              40         2
# 6            7  Female   35      18               6         2
# 8            9    Male   64      19               3         2
# 10          11    Male   67      19              14         2
# 1            2    Male   21      15              81         3
# 3            4  Female   23      16              77         3
# 5            6  Female   22      17              76         3
# 7            8  Female   23      18              94         3
# 9           10  Female   30      19              72         3
# 11          12  Female   35      19              99         3
# 43          44  Female   31      39              61         0
# 46          47  Female   50      40              55         0
# 47          48  Female   27      40              47         0

# %% [markdown]
# ## Visualising diverse groups

# %%
group = diverse_groups[0]
sns.scatterplot(data = group, x = "Income", y = "Spending Score", hue = "Clusters", palette = "Set2")
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Spending Score'>

# %%
for group_temp in diverse_groups:
    print(group_temp["Clusters"].value_counts())
# Out:
# 0    20
# 4    10
# 1     9
# 2     6
# 3     6
# Name: Clusters, dtype: int64
# 0    20
# 4    10
# 1     9
# 2     6
# 3     6
# Name: Clusters, dtype: int64
# 0    20
# 4    10
# 1     9
# 2     6
# 3     6
# Name: Clusters, dtype: int64
# 0    20
# 4     9
# 1     8
# 2     5
# 3     4
# Name: Clusters, dtype: int64

# %% [markdown]
# ## Creating diverse customer groups (different approach)

# %%
def sort_dataframe(df):
    sorted_dataframe = df.sort_values(by = "Clusters")
    return sorted_dataframe

sort_dataframe(df1).head()
# Out:
#     CustomerID  Gender  Age  Income  Spending Score  Clusters
# 99         100    Male   20      61              49         0
# 83          84  Female   46      54              44         0
# 82          83    Male   67      54              41         0
# 81          82    Male   38      54              55         0
# 80          81    Male   57      54              51         0

# %% [markdown]
# ## Keeping two customers together: merging rows before clustering

# %%
df2 = df1.drop("Clusters", axis=1)

def merge_customers(df, id1, id2):
    customer1 = df[df["CustomerID"] == id1]
    customer2 = df[df["CustomerID"] == id2]
    #customer_id = str(customer1["CustomerID"]) + "_" + str(customer2["CustomerID"])
    #average_age = (customer1["Age"] + customer2["Age"])/2
    #average_income = (customer1["Income"] + customer2["Income"])/2
    #average_spending_score = (customer1["Spending Score"] + customer2["Spending Score"])/2
    #if customer1["Gender"] == customer2["Gender"]:
    #    determine_gender = customer1["Gender"]
    #else:
    #    determine_gender = np.nan  
    #merged_customers = pd.DataFrame({"CustomerID": [customer_id],
    #                                 "Gender": [determine_gender],
    #                                 "Age": [average_age],
    #                                 "Income": [average_income],
    #                                 "Spending Score": [average_spending_score]})
    #df.append(merged_customers)
    #return merged_customers
    print(customer1)
    print(customer2)

merge_customers(df2, 1, 2)
    

    
#df.iloc[-1,2]
# Out:
#    CustomerID Gender  Age  Income  Spending Score
# 0           1   Male   19      15              39
#    CustomerID Gender  Age  Income  Spending Score
# 1           2   Male   21      15              81
